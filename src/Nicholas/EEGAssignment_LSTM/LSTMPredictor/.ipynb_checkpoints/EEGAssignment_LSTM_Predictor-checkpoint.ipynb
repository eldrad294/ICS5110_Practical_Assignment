# %%
# %reset -f
testID = 0

# %%
import os
import shutil

import pandas as pd
import numpy as np
import math as mt
import matplotlib.pyplot as plt
import seaborn as sns

# Keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.utils import plot_model

# SkLearn
import sklearn.preprocessing as SklPreProcessing
import sklearn.metrics as SklMetrics
from sklearn.preprocessing import normalize
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score


# %matplotlib inline

# %%
class Scoring_Functions():
    #
    def __init__(self, y_pred, y_true):
        self.y_pred = y_pred
        self.y_true = y_true
    #
    def accuracy(self):
        # http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score
        return str(accuracy_score(self.y_true, self.y_pred) * 100) + "%"
    #
    def precision(self):
        # http: // scikit - learn.org / stable / modules / generated / sklearn.metrics.precision_score.html  # sklearn.metrics.precision_score
        return str(precision_score(self.y_true, self.y_pred, average='weighted')* 100) + '%'
    #
    def recall(self):
        # http://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html#sklearn.metrics.recall_score
        return str(recall_score(self.y_true, self.y_pred, average='weighted') * 100) + '%'
    #
    def f_measure(self):
        # http://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html#sklearn.metrics.f1_score
        return str(f1_score(self.y_true, self.y_pred, average='weighted') * 100) + '%'
    #
    def scoring_results(self):
        return "Accuracy: " + str(self.accuracy()) + "\nPrecision: " + str(self.precision()) + "\nRecall: " + str(self.recall()) + "\nFMeasure: " + str(self.f_measure())

# %%
class LSTMPredictor:
    ############################
    # MetaData
    __testID = None
    __cmdCount = 0
    __cmdHistory = ''
    __resultsRootDir = 'results'
    ############################
    # Dataset info
    __eegData = None
    __eegHeader = None
    __testDataIndex = 0
    __trainDataFileName = None
    __testDataFileName = None
    ############################
    # ML model info
    __model = None
    __trainTestMap = None
    ############################
   
    def __init__(self, testID, trainFilename, testFilename):
        self.__testID = str(testID).zfill(5)
        self.__createTestResultsDir()
        self.__trainDataFileName = trainFilename
        self.__testDataFileName = testFilename
        self.ResetState()
        
    def ResetState(self):
        tmpFileName = ''
        self.__cmdHistory = ''
        self.__cmdCount = 0
        self.__loadData()
    
    ###########################################################################
    # Plot methods
    def PlotFeatures(self, filePrefix=None, figWidth=20, figHeight=20):
        self.__addToHistory('PlotFeatures_filePrefix:' + str(filePrefix))
        fig = plt.figure()
        fig.set_figwidth(figWidth)
        fig.set_figheight(figHeight)
        
        featureCount = len(self.__eegHeader) - 1
        idxSubplot = 0
        
        for itr in range(featureCount):
            idxSubplot = idxSubplot + 1
            currAx = fig.add_subplot(featureCount + 1, 1, idxSubplot)
            currAx.grid()
            currAx.plot(self.__eegData[:, itr])
            currAx.set_title(self.__eegHeader[itr])
        
        idxSubplot = idxSubplot + 1
        currAx = fig.add_subplot(featureCount + 1, 1, idxSubplot)
        currAx.grid()
        currAx.plot(self.__eegData[:, -1])
        currAx.set_title(self.__eegHeader[-1])

        if filePrefix is None:
            plt.show()
        else:
            pathToFile = self.__resultsRootDir + "/" + self.__testID + "/" + filePrefix
            plt.savefig(pathToFile)
            
    def PlotBoxPlots(self, filePrefix=None, figWidth=20, figHeight=20):
        self.__addToHistory('PlotBoxPlots_filePrefix:' + str(filePrefix))
        fig = plt.figure()
        fig.set_figwidth(figWidth)
        fig.set_figheight(figHeight)
        
        ax1 = fig.add_subplot(2, 1, 1)
        ax1.set_title('Feature range: Full')
        ax1.boxplot(self.__eegData[:, :-1]
                    , sym='b.'
                    , vert=False
                    , whis='range'
                    , labels=self.__eegHeader[:-1]
                    , meanline=True
                    , showbox=True
                    , showfliers=True)
        
        ax2 = fig.add_subplot(2, 1, 2)
        ax2.set_title('Feature range: [5%, 95%]')
        ax2.boxplot(self.__eegData[:, :-1]
                    , sym='b.'
                    , vert=False
                    , whis=[5, 95]
                    , labels=self.__eegHeader[:-1]
                    , meanline=True
                    , showbox=True
                    , showfliers=False)
        
        if filePrefix is not None:
            pathToFile = self.__resultsRootDir + "/" + self.__testID + "/" + filePrefix
            plt.savefig(pathToFile)
            
    def PlotMeanDistribution(self, filePrefix=None, figWidth=20, figHeight=20):
        self.__addToHistory('PlotMeanDistribution_filePrefix:' + str(filePrefix))
        idxEyeClosed = np.where(self.__eegData[:, -1] == 1)[0]
        idxEyeOpened = np.where(self.__eegData[:, -1] == 0)[0]
        
        featureCount = len(self.__eegHeader) - 1
        xTick = np.array(range(featureCount))
        
        fig = plt.figure()
        fig.set_figwidth(figWidth)
        fig.set_figheight(figHeight)

        ax = fig.add_subplot(1, 1, 1)
        ax.grid()
        ax.set_title('Mean Distribution')
        ax.set_xticklabels(self.__eegHeader[0:-1])
        ax.set_xticks(xTick)

        ax.plot(xTick, self.__eegData[idxEyeOpened][:, 0:featureCount].mean(axis=0), 'bo')
        ax.plot(xTick, self.__eegData[idxEyeClosed][:, 0:featureCount].mean(axis=0), 'ro')
        ax.plot(xTick, self.__eegData[:, 0:featureCount].mean(axis=0), 'go')

        ax.legend(['Eye Open', 'Eye Closed', 'Both'])
        
        if filePrefix is not None:
            pathToFile = self.__resultsRootDir + "/" + self.__testID + "/" + filePrefix
            plt.savefig(pathToFile)

    def PlotStdDevDistribution(self, filePrefix=None, figWidth=20, figHeight=20):
        self.__addToHistory('PlotStdDevDistribution_filePrefix:' + str(filePrefix))
        idxEyeClosed = np.where(self.__eegData[:, -1] == 1)[0]
        idxEyeOpened = np.where(self.__eegData[:, -1] == 0)[0]
        
        featureCount = len(self.__eegHeader) - 1
        xTick = np.array(range(featureCount))
        
        fig = plt.figure()
        fig.set_figwidth(figWidth)
        fig.set_figheight(figHeight)

        ax = fig.add_subplot(1, 1, 1)
        ax.grid()
        ax.set_title('Standard Deviation Distribution')
        ax.set_xticklabels(self.__eegHeader[0:-1])
        ax.set_xticks(xTick)

        ax.plot(xTick, self.__eegData[idxEyeOpened][:, 0:featureCount].std(axis=0), 'bo')
        ax.plot(xTick, self.__eegData[idxEyeClosed][:, 0:featureCount].std(axis=0), 'ro')
        ax.plot(xTick, self.__eegData[:, 0:featureCount].std(axis=0), 'go')

        ax.legend(['Eye Open', 'Eye Closed', 'Both'])
        
        if filePrefix is not None:
            pathToFile = self.__resultsRootDir + "/" + self.__testID + "/" + filePrefix
            plt.savefig(pathToFile)
            
    def FeatureCorrelationMatrix(self, filePrefix=None, figWidth=20, figHeight=20):
        self.__addToHistory('FeatureCorrelationMatrix_filePrefix:' + str(filePrefix))
        # Compute the correlation matrix
        corr = pd.DataFrame(data=self.__eegData[:, :-1], columns=list(self.__eegHeader[:-1])).corr()
        
        # Generate a mask for the upper triangle
        mask = np.zeros_like(corr, dtype=np.bool)
        mask[np.triu_indices_from(mask)] = True
        
        # Set up the matplotlib figure
        fig = plt.figure()
        fig.set_figwidth(figWidth)
        fig.set_figheight(figHeight)
        
        ax = fig.add_subplot(1, 1, 1)
        ax.set_title("Feature correlation matrix")
        
        # Generate a custom diverging colormap
        cmap = sns.diverging_palette(240, 10, as_cmap=True)
        
        # Draw the heatmap
        sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1.0, vmin=-1.0, center=0,
                    square=True, linewidths=.5, cbar_kws={"shrink": .5})
        
        if filePrefix is not None:
            pathToFile = self.__resultsRootDir + "/" + self.__testID + "/" + filePrefix
            plt.savefig(pathToFile)

    ###########################################################################
    # Getters
    def GetFeatureNames(self):
        return self.__eegHeader[:-1]
    
    def GetCmdHistory(self):
        return self.__cmdHistory
    ###########################################################################
    # Dataset operations
    def RemoveFeatures(self, indices):
        assert isinstance(indices, list), 'Parameter must be a list'

        self.__addToHistory('RemoveFeatures:' + ','.join(str(x) for x in indices))
        self.__eegHeader = np.delete(self.__eegHeader, indices)
        self.__eegData = np.delete(self.__eegData, indices, axis=1)
    
    def RemoveOutliers(self, upperLimit=None, lowerLimit=None):
        outLierIndexes = set()
        result = {}
        result['upper'] = set()
        result['lower'] = set()
        
        self.__addToHistory('RemoveOutliers_Upper:' + str(upperLimit)
                            + '_Lower:' + str(lowerLimit))
        featureCount = len(self.__eegHeader) - 1

        if upperLimit is not None:
            for itr in range(featureCount):
                outLiers = np.where(self.__eegData[:, itr] > upperLimit)[0]
                if len(outLiers) > 0:
                    for i in xrange(len(outLiers)):
                        result['upper'].add(outLiers[i])

        if lowerLimit is not None:
            for itr in range(featureCount):
                outLiers = np.where(self.__eegData[:, itr] < lowerLimit)[0]
                if len(outLiers) > 0:
                    for i in xrange(len(outLiers)):
                        result['lower'].add(outLiers[i])
                        
        deleteIndexes = list(result['upper'].union(result['lower']))
        self.__eegData = np.delete(self.__eegData, deleteIndexes, axis=0)
        
        return result

    def NormalizeData(self, normFunc='MinMax'):
        self.__addToHistory('NormalizeData_Func:' + normFunc)
        
        if normFunc == 'MinMax':
            scaler = SklPreProcessing.MinMaxScaler(feature_range=(0, 1))
            self.__eegData = scaler.fit_transform(self.__eegData)
        else:
            self.__eegData = normalize(self.__eegData, norm=normFunc)
        
    ###########################################################################
    # Keras LSTM model
    def CompileModel(self, lagCount, neuronCount, dropOut,
                     modelArchitectureFilename,
                     lstmStackCount=1, useLaggedOutput=True,
                     lossFunc='mae', optimizerFunc='adam'):
        assert lstmStackCount > 0, 'lstmStackCount must be > 0'
        self.__addToHistory('CompileModel_Lag:' + str(lagCount)
                            + '_NeuronCount:' + str(neuronCount)
                            + '_DropOut:' + str(dropOut)
                            + '_useLaggedOutput:' + str(useLaggedOutput)
                            + '_LossFunc:' + str(lossFunc)
                            + '_OptimizerFunc:' + str(optimizerFunc)
                            + '_lstmStackCount:' + str(lstmStackCount))
        
        supervisedDataset = self.__timeSeriesToSupervised(lagCount, useLaggedOutput)
        featureCount = len(self.__eegHeader) - 1
        
        values = supervisedDataset.values
        
        trainingSet = values[:self.__testDataIndex, :]
        testingSet = values[self.__testDataIndex:, :]
        
        pastInputCount = (featureCount + 1) * lagCount
        self.__trainTestMap = {}

        self.__trainTestMap['trainingSet_inFeatures'] = trainingSet[:, :pastInputCount]
        self.__trainTestMap['trainingSet_outFeature'] = trainingSet[:, -1]
        
        self.__trainTestMap['testingSet_inFeatures'] = testingSet[:, :pastInputCount]
        self.__trainTestMap['testingSet_outFeature'] = testingSet[:, -1]
        
        # Reshape input to be 3D [samples, timesteps, features]
        featureDimSize = (featureCount + 1)
        
        self.__trainTestMap['trainingSet_inFeatures_reShaped'] = self.__trainTestMap['trainingSet_inFeatures'].reshape(
            (self.__trainTestMap['trainingSet_inFeatures'].shape[0], lagCount, featureDimSize))
        
        self.__trainTestMap['testingSet_inFeatures_reShaped'] = self.__trainTestMap['testingSet_inFeatures'].reshape(
            (self.__trainTestMap['testingSet_inFeatures'].shape[0], lagCount, featureDimSize))
        
        # Design network
        self.__model = Sequential()
        
        if lstmStackCount == 1:
            self.__model.add(
                LSTM(neuronCount,
                     input_shape=(
                         self.__trainTestMap['trainingSet_inFeatures_reShaped'].shape[1],
                         self.__trainTestMap['trainingSet_inFeatures_reShaped'].shape[2])
                    )
            )
        else:
            self.__model.add(
                LSTM(neuronCount,
                     input_shape=(
                         self.__trainTestMap['trainingSet_inFeatures_reShaped'].shape[1],
                         self.__trainTestMap['trainingSet_inFeatures_reShaped'].shape[2]),
                     return_sequences=True)
            )
            
            for i in range(lstmStackCount - 1):
                returnSequence = (i != (lstmStackCount - 2))
                self.__model.add(LSTM(neuronCount, return_sequences=returnSequence))
        
        self.__model.add(Dense(1))
        self.__model.compile(loss=lossFunc, optimizer=optimizerFunc)
        
        # Visualize LSTM network
        pathToFile = self.__resultsRootDir + "/" + self.__testID + "/" + modelArchitectureFilename
        plot_model(self.__model, to_file=pathToFile, show_shapes=True)
        
    def FitModel(self, epochCount, batchSize,
                 resultsFile,
                 lossFuncFilePrefix=None,
                 predictionFilePrefix=None,
                 figWidth=20, figHeight=20, verbosity=2):
        assert self.__model != None, 'Model not compiled'
        
        self.__addToHistory('FitModel_EpochCount:' + str(epochCount)
                            + '_BatchSize:' + str(batchSize)
                            + '_lossFuncFilePrefix:' + str(lossFuncFilePrefix)
                            + '_predictionFilePrefix:' + str(predictionFilePrefix))
        
        # Fit model
        history = self.__model.fit(self.__trainTestMap['trainingSet_inFeatures_reShaped'],
                                 self.__trainTestMap['trainingSet_outFeature'],
                                 epochs=epochCount,
                                 batch_size=batchSize,
                                 validation_data=(
                                     self.__trainTestMap['testingSet_inFeatures_reShaped'],
                                     self.__trainTestMap['testingSet_outFeature']
                                 ),
                                 verbose=verbosity, shuffle=False)
        
        fig = plt.figure()
        fig.set_figwidth(figWidth)
        fig.set_figheight(figHeight)

        ax = fig.add_subplot(1, 1, 1)
        ax.grid()
        ax.set_title('Loss Function')
        ax.plot(history.history['loss'], label='train')
        ax.plot(history.history['val_loss'], label='test')
        plt.legend(['train', 'test'])
                    
        if lossFuncFilePrefix is not None:
            pathToFile = self.__resultsRootDir + "/" + self.__testID + "/" + lossFuncFilePrefix
            plt.savefig(pathToFile)

        testDataPrediction = self.__model.predict_classes(self.__trainTestMap['testingSet_inFeatures_reShaped'])
        testDataPredictionRaw = self.__model.predict(self.__trainTestMap['testingSet_inFeatures_reShaped'])
                
        scoringMetrics = Scoring_Functions(testDataPrediction, self.__trainTestMap['testingSet_outFeature'])
        self.__writeResultsToFile(resultsFile, scoringMetrics.scoring_results())
        print 'Results:\n' + scoringMetrics.scoring_results()

        fig = plt.figure()
        fig.set_figwidth(figWidth)
        fig.set_figheight(figHeight)
        
        ax1 = fig.add_subplot(3, 1, 1)
        ax1.grid()
        ax1.set_title('Expected')
        ax1.plot(self.__trainTestMap['testingSet_outFeature'])

        ax2 = fig.add_subplot(3, 1, 2)
        ax2.grid()
        ax2.set_title('Prediction - With rounding')
        ax2.plot(testDataPrediction)

        ax3 = fig.add_subplot(3, 1, 3)
        ax3.grid()
        ax3.set_title('Prediction - Without rounding')
        ax3.plot(testDataPredictionRaw)

        if predictionFilePrefix is not None:
            pathToFile = self.__resultsRootDir + "/" + self.__testID + "/" + predictionFilePrefix
            plt.savefig(pathToFile)

        # Reset __model
        self.__model = None
        self.__trainTestMap = None
    
    ###########################################################################
    # Private methods
    def __createTestResultsDir(self):
        dirName = "%s/%s" % (self.__resultsRootDir, self.__testID)
        if os.path.exists(dirName):
            shutil.rmtree(dirName)
        os.makedirs(dirName)
        
    def __loadData(self):
        self.__eegHeader = np.genfromtxt(self.__trainDataFileName, delimiter=',', max_rows=1, dtype=str)
        self.__eegData = np.genfromtxt(self.__trainDataFileName, delimiter=',', skip_header=1)
        testDataSet = np.genfromtxt(self.__testDataFileName, delimiter=',', skip_header=1)
        
        self.__testDataIndex = self.__eegData.shape[0]
        self.__eegData = np.append(self.__eegData, testDataSet, axis=0)

    def __timeSeriesToSupervised(self, lagCount, useLaggedOutput):
        featureCount = len(self.__eegHeader) - 1

        cols, names = list(), list()
        dfInput = pd.DataFrame(self.__eegData[:, :-1])
        dfOutput = pd.DataFrame(self.__eegData[:, -1])
        
        for i in range(lagCount, 0, -1):
            cols.append(dfInput.shift(i))
            if useLaggedOutput:
                cols.append(dfOutput.shift(i))
            else:
                # Set the lagged output variable to a constant 0.5
                tmp = len(dfOutput.shift(i))
                cols.append(pd.DataFrame(np.ones(tmp) * 0.5))
            
            names += [('%s(t-%d)' % (self.__eegHeader[j], i)) for j in range(featureCount)]
            names += [('%s(t-%d)' % (self.__eegHeader[-1], i))]

        cols.append(dfInput)
        cols.append(dfOutput)
        names += [('%s(t)' % self.__eegHeader[j]) for j in range(featureCount)]
        names += [('%s(t)' % self.__eegHeader[-1])]

        agg = pd.concat(cols, axis=1)
        agg.columns = names

        # Drop rows containing NaN values
        agg.dropna(inplace=True)
        return agg
    
    def __addToHistory(self, newCmd):
        tmpStr = ''
        if self.__cmdCount > 0:
            tmpStr += '\n'
            for itr in range(self.__cmdCount):
                tmpStr += '+'
                
        tmpStr += newCmd
        self.__cmdHistory += tmpStr
        self.__cmdCount += 1
        
    def __writeResultsToFile(self, resFilename, results):
        pathToResultsFile = self.__resultsRootDir + "/" + self.__testID + "/" + resFilename
        resString = ''
        
        if os.path.exists(pathToResultsFile):
            resString = '\n\n-----------------------------------------------------------------\n'
            fileMode = 'a' # Append
        else:
            fileMode = 'w' # Create
        
        text_file = open(pathToResultsFile, fileMode)
        
        resString += 'Results:\n'
        resString += results
        resString += '\n\nCommand history:\n----------------\n'
        resString += self.__cmdHistory        

        text_file.write(resString)
        text_file.close()
    ###########################################################################

# %% [markdown]
# ### Dataset analysis plots

# %%
testID = 1

print "TestID: ", testID
predictor = LSTMPredictor(testID
                          , trainFilename='EEGEyeState_Training.arff.csv'
                          , testFilename='EEGEyeState_Testing.arff.csv')

predictor.PlotFeatures(filePrefix='01_01_RawData')
predictor.FeatureCorrelationMatrix(filePrefix='01_02_CorrelationMatrix_RawData')
predictor.PlotBoxPlots(filePrefix='01_03_BoxPlot_RawData')
predictor.PlotMeanDistribution('01_04_MeanDistribution_RawData')
predictor.PlotStdDevDistribution('01_05_StdDevDistribution_RawData')

res = predictor.RemoveOutliers(upperLimit=5000)
predictor.PlotFeatures(filePrefix='02_01_RemovedOutliers')
predictor.FeatureCorrelationMatrix(filePrefix='02_02_CorrelationMatrix_OutliersRemoved')
predictor.PlotBoxPlots(filePrefix='02_03_BoxPlot_OutliersRemove')
predictor.PlotMeanDistribution('02_04_MeanDistribution_OutliersRemove')
predictor.PlotStdDevDistribution('02_05_StdDevDistribution_OutliersRemove')

predictor.NormalizeData()
predictor.PlotFeatures(filePrefix='03_01_NormalizedData')
predictor.FeatureCorrelationMatrix(filePrefix='03_02_CorrelationMatrix_NormalizedData')
predictor.PlotBoxPlots(filePrefix='03_03_BoxPlot_NormalizedData')
predictor.PlotMeanDistribution('03_04_MeanDistribution_NormalizedData')
predictor.PlotStdDevDistribution('03_05_StdDevDistribution_NormalizedData')
# Out:
# TestID:  1

# %% [markdown]
# ### Prediction
# - Outliers not removed
# - Data not normalized
# - lagValue = 1
# - epochCount = 50
# - batchSize = 50

# %%
testID = 2
print "TestID: ", testID

resultsFilename = 'TestResults.txt'

predictor = LSTMPredictor(testID
                          , trainFilename='EEGEyeState_Training.arff.csv'
                          , testFilename='EEGEyeState_Testing.arff.csv')

lagValue = 1
predictor.CompileModel(lagCount=lagValue
               , neuronCount=50
               , dropOut=0.0
               , useLaggedOutput=True
               , modelArchitectureFilename='01_modelArchitecture')

predictor.FitModel(epochCount=50
           , batchSize=50
           , resultsFile=resultsFilename
           , lossFuncFilePrefix='01_lossFile'
           , predictionFilePrefix='01_predictionFile'
           , verbosity=2)
# Out:
# TestID:  2
# Train on 10000 samples, validate on 4979 samples
# Epoch 1/50
#  - 1s - loss: 0.5752 - val_loss: 0.5105
# Epoch 2/50
#  - 0s - loss: 0.5326 - val_loss: 0.7018
# Epoch 3/50
#  - 0s - loss: 0.4697 - val_loss: 0.6510
# Epoch 4/50
#  - 0s - loss: 0.4864 - val_loss: 0.6574
# Epoch 5/50
#  - 0s - loss: 0.4864 - val_loss: 0.6614
# Epoch 6/50
#  - 0s - loss: 0.4830 - val_loss: 0.6492
# Epoch 7/50
#  - 0s - loss: 0.4897 - val_loss: 0.6687
# Epoch 8/50
#  - 0s - loss: 0.4795 - val_loss: 0.6409
# Epoch 9/50
#  - 0s - loss: 0.4930 - val_loss: 0.6760
# Epoch 10/50
#  - 0s - loss: 0.4762 - val_loss: 0.6334
# Epoch 11/50
#  - 0s - loss: 0.4964 - val_loss: 0.6841
# Epoch 12/50
#  - 0s - loss: 0.4747 - val_loss: 0.6408
# Epoch 13/50
#  - 0s - loss: 0.4930 - val_loss: 0.6771
# Epoch 14/50
#  - 0s - loss: 0.4763 - val_loss: 0.6345
# Epoch 15/50
#  - 0s - loss: 0.4963 - val_loss: 0.6852
# Epoch 16/50
#  - 0s - loss: 0.4747 - val_loss: 0.6419
# Epoch 17/50
#  - 0s - loss: 0.4929 - val_loss: 0.6782
# Epoch 18/50
#  - 0s - loss: 0.4763 - val_loss: 0.6356
# Epoch 19/50
#  - 0s - loss: 0.4962 - val_loss: 0.6863
# Epoch 20/50
#  - 0s - loss: 0.4748 - val_loss: 0.6430
# Epoch 21/50
#  - 0s - loss: 0.4929 - val_loss: 0.6792
# Epoch 22/50
#  - 0s - loss: 0.4764 - val_loss: 0.6367
# Epoch 23/50
#  - 1s - loss: 0.4962 - val_loss: 0.6873
# Epoch 24/50
#  - 0s - loss: 0.4731 - val_loss: 0.6293
# Epoch 25/50
#  - 0s - loss: 0.4994 - val_loss: 0.6953
# Epoch 26/50
#  - 0s - loss: 0.4717 - val_loss: 0.6366
# Epoch 27/50
#  - 0s - loss: 0.4961 - val_loss: 0.6884
# Epoch 28/50
#  - 0s - loss: 0.4732 - val_loss: 0.6303
# Epoch 29/50
#  - 0s - loss: 0.4994 - val_loss: 0.6964
# Epoch 30/50
#  - 0s - loss: 0.4718 - val_loss: 0.6377
# Epoch 31/50
#  - 0s - loss: 0.4931 - val_loss: 0.6735
# Epoch 32/50
#  - 0s - loss: 0.4797 - val_loss: 0.6464
# Epoch 33/50
#  - 0s - loss: 0.4897 - val_loss: 0.6653
# Epoch 34/50
#  - 0s - loss: 0.4830 - val_loss: 0.6538
# Epoch 35/50
#  - 0s - loss: 0.4863 - val_loss: 0.6572
# Epoch 36/50
#  - 0s - loss: 0.4863 - val_loss: 0.6612
# Epoch 37/50
#  - 0s - loss: 0.4829 - val_loss: 0.6489
# Epoch 38/50
#  - 0s - loss: 0.4897 - val_loss: 0.6685
# Epoch 39/50
#  - 0s - loss: 0.4830 - val_loss: 0.6569
# Epoch 40/50
#  - 0s - loss: 0.4863 - val_loss: 0.6603
# Epoch 41/50
#  - 0s - loss: 0.4863 - val_loss: 0.6642
# Epoch 42/50
#  - 0s - loss: 0.4829 - val_loss: 0.6520
# Epoch 43/50
#  - 0s - loss: 0.4896 - val_loss: 0.6715
# Epoch 44/50
#  - 0s - loss: 0.4796 - val_loss: 0.6437
# Epoch 45/50
#  - 0s - loss: 0.4929 - val_loss: 0.6787
# Epoch 46/50
#  - 0s - loss: 0.4763 - val_loss: 0.6362
# Epoch 47/50
#  - 0s - loss: 0.4962 - val_loss: 0.6868
# Epoch 48/50
#  - 1s - loss: 0.4748 - val_loss: 0.6435
# Epoch 49/50
#  - 0s - loss: 0.4929 - val_loss: 0.6798
# Epoch 50/50
#  - 0s - loss: 0.4763 - val_loss: 0.6364
# Results:
# Accuracy: 23.2777666198%
# Precision: 43.7771612442%
# Recall: 23.2777666198%
# FMeasure: 8.82621475069%

# %% [markdown]
# ### Prediction
# - Outliers not removed
# - Data not normalized
# - lagValue = 1
# - epochCount = 1000
# - batchSize = 50

# %%
testID = 3
print "TestID: ", testID

resultsFilename = 'TestResults.txt'

predictor = LSTMPredictor(testID
                          , trainFilename='EEGEyeState_Training.arff.csv'
                          , testFilename='EEGEyeState_Testing.arff.csv')

lagValue = 1
predictor.CompileModel(lagCount=lagValue
               , neuronCount=50
               , dropOut=0.0
               , useLaggedOutput=True
               , modelArchitectureFilename='01_modelArchitecture')

predictor.FitModel(epochCount=1000
           , batchSize=50
           , resultsFile=resultsFilename
           , lossFuncFilePrefix='01_lossFile'
           , predictionFilePrefix='01_predictionFile'
           , verbosity=2)
# Out:
# TestID:  3
# Train on 10000 samples, validate on 4979 samples
# Epoch 1/1000
#  - 1s - loss: 0.5711 - val_loss: 0.3426
# Epoch 2/1000
#  - 0s - loss: 0.5457 - val_loss: 0.4112
# Epoch 3/1000
#  - 0s - loss: 0.5312 - val_loss: 0.4798
# Epoch 4/1000
#  - 0s - loss: 0.5167 - val_loss: 0.5485
# Epoch 5/1000
#  - 0s - loss: 0.5022 - val_loss: 0.6172
# Epoch 6/1000
#  - 0s - loss: 0.4877 - val_loss: 0.6859
# Epoch 7/1000
#  - 0s - loss: 0.4732 - val_loss: 0.7546
# Epoch 8/1000
#  - 0s - loss: 0.4527 - val_loss: 0.7406
# Epoch 9/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7209
# Epoch 10/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7338
# Epoch 11/1000
#  - 0s - loss: 0.4566 - val_loss: 0.7240
# Epoch 12/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7309
# Epoch 13/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7267
# Epoch 14/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7279
# Epoch 15/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7294
# Epoch 16/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7249
# Epoch 17/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7320
# Epoch 18/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7220
# Epoch 19/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7346
# Epoch 20/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7192
# Epoch 21/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7375
# Epoch 22/1000
#  - 0s - loss: 0.4547 - val_loss: 0.7219
# Epoch 23/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7350
# Epoch 24/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7196
# Epoch 25/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7379
# Epoch 26/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7223
# Epoch 27/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7354
# Epoch 28/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 29/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 30/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 31/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7412
# Epoch 32/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 33/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7387
# Epoch 34/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 35/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 36/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 37/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 38/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7235
# Epoch 39/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 40/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 41/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 42/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7288
# Epoch 43/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7303
# Epoch 44/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7259
# Epoch 45/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7329
# Epoch 46/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7229
# Epoch 47/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7355
# Epoch 48/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7202
# Epoch 49/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7384
# Epoch 50/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7175
# Epoch 51/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7413
# Epoch 52/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7201
# Epoch 53/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7388
# Epoch 54/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7179
# Epoch 55/1000
#  - 0s - loss: 0.4626 - val_loss: 0.7359
# Epoch 56/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7206
# Epoch 57/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7388
# Epoch 58/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7179
# Epoch 59/1000
#  - 0s - loss: 0.4626 - val_loss: 0.7360
# Epoch 60/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7206
# Epoch 61/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7331
# Epoch 62/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7233
# Epoch 63/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7360
# Epoch 64/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7203
# Epoch 65/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7385
# Epoch 66/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7176
# Epoch 67/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7414
# Epoch 68/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7202
# Epoch 69/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7331
# Epoch 70/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7234
# Epoch 71/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7360
# Epoch 72/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7204
# Epoch 73/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7386
# Epoch 74/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7176
# Epoch 75/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7414
# Epoch 76/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 77/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 78/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7234
# Epoch 79/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7303
# Epoch 80/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 81/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7331
# Epoch 82/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 83/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 84/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 85/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 86/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 87/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 88/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 89/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 90/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 91/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 92/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 93/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 94/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7235
# Epoch 95/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 96/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 97/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 98/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7288
# Epoch 99/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7244
# Epoch 100/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 101/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7273
# Epoch 102/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 103/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7300
# Epoch 104/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7255
# Epoch 105/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 106/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7225
# Epoch 107/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 108/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7198
# Epoch 109/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 110/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 111/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 112/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 113/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 114/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 115/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 116/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 117/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 118/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 119/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 120/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 121/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 122/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 123/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 124/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 125/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 126/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 127/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 128/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 129/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 130/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7176
# Epoch 131/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 132/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 133/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 134/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7234
# Epoch 135/1000
#  - 0s - loss: 0.4602 - val_loss: 0.7303
# Epoch 136/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 137/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7331
# Epoch 138/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 139/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 140/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 141/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 142/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 143/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 144/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 145/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 146/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 147/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 148/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 149/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 150/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7235
# Epoch 151/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 152/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 153/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 154/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 155/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 156/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 157/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7273
# Epoch 158/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 159/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7300
# Epoch 160/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7255
# Epoch 161/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 162/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 163/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 164/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7198
# Epoch 165/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 166/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 167/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 168/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 169/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 170/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 171/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 172/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 173/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 174/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 175/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 176/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 177/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 178/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 179/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 180/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 181/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 182/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 183/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 184/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 185/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 186/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 187/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 188/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 189/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 190/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7235
# Epoch 191/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7303
# Epoch 192/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 193/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7332
# Epoch 194/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 195/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 196/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 197/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 198/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 199/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 200/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 201/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 202/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7178
# Epoch 203/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 204/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 205/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 206/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7236
# Epoch 207/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 208/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 209/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 210/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 211/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 212/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 213/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7273
# Epoch 214/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 215/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7300
# Epoch 216/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7256
# Epoch 217/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 218/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 219/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 220/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 221/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 222/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 223/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 224/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 225/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 226/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 227/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 228/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 229/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 230/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 231/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 232/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 233/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 234/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 235/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 236/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 237/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 238/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 239/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 240/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 241/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 242/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 243/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 244/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 245/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 246/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7235
# Epoch 247/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7303
# Epoch 248/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 249/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7332
# Epoch 250/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 251/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7358
# Epoch 252/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 253/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 254/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 255/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 256/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 257/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 258/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7178
# Epoch 259/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 260/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 261/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 262/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7236
# Epoch 263/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 264/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 265/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 266/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 267/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 268/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 269/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7274
# Epoch 270/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 271/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7300
# Epoch 272/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7256
# Epoch 273/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 274/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 275/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 276/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 277/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 278/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 279/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 280/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 281/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 282/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 283/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 284/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 285/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 286/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 287/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 288/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 289/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 290/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 291/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 292/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 293/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 294/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7176
# Epoch 295/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 296/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 297/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 298/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7234
# Epoch 299/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7303
# Epoch 300/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 301/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7332
# Epoch 302/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 303/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 304/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 305/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 306/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 307/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 308/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 309/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 310/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7178
# Epoch 311/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 312/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 313/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 314/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7236
# Epoch 315/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 316/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 317/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 318/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 319/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 320/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 321/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7273
# Epoch 322/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 323/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7300
# Epoch 324/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7256
# Epoch 325/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 326/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 327/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 328/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7198
# Epoch 329/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 330/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 331/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 332/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 333/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 334/1000
#  - 1s - loss: 0.4548 - val_loss: 0.7225
# Epoch 335/1000
#  - 1s - loss: 0.4613 - val_loss: 0.7356
# Epoch 336/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 337/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 338/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 339/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 340/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 341/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 342/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 343/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 344/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 345/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 346/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 347/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 348/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 349/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 350/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 351/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 352/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 353/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 354/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7235
# Epoch 355/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7303
# Epoch 356/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 357/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7332
# Epoch 358/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 359/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7358
# Epoch 360/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 361/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 362/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 363/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 364/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 365/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 366/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7178
# Epoch 367/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 368/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 369/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 370/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7236
# Epoch 371/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 372/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 373/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 374/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 375/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 376/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 377/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7273
# Epoch 378/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 379/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7300
# Epoch 380/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7256
# Epoch 381/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 382/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 383/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 384/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 385/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 386/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 387/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 388/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 389/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 390/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 391/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 392/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 393/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 394/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 395/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 396/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 397/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 398/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 399/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 400/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 401/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 402/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7176
# Epoch 403/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 404/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 405/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 406/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7234
# Epoch 407/1000
#  - 0s - loss: 0.4602 - val_loss: 0.7303
# Epoch 408/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 409/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7331
# Epoch 410/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 411/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 412/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 413/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 414/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 415/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 416/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 417/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 418/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 419/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 420/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 421/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 422/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7235
# Epoch 423/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 424/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 425/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 426/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 427/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 428/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 429/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7273
# Epoch 430/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 431/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7300
# Epoch 432/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7256
# Epoch 433/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 434/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 435/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 436/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7198
# Epoch 437/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 438/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 439/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 440/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 441/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 442/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 443/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 444/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 445/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 446/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 447/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 448/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 449/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 450/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 451/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 452/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 453/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 454/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 455/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 456/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 457/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 458/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 459/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 460/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 461/1000
#  - 1s - loss: 0.4614 - val_loss: 0.7332
# Epoch 462/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7235
# Epoch 463/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7303
# Epoch 464/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 465/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7332
# Epoch 466/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 467/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 468/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 469/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 470/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 471/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 472/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 473/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 474/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7178
# Epoch 475/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 476/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 477/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 478/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7236
# Epoch 479/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 480/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 481/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 482/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 483/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 484/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 485/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7273
# Epoch 486/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 487/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7300
# Epoch 488/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7256
# Epoch 489/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 490/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 491/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 492/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 493/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 494/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 495/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 496/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 497/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 498/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 499/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 500/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 501/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 502/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 503/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 504/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 505/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 506/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 507/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 508/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 509/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 510/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 511/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 512/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 513/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 514/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 515/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 516/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 517/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 518/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7235
# Epoch 519/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7303
# Epoch 520/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 521/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7332
# Epoch 522/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 523/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7358
# Epoch 524/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 525/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 526/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 527/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 528/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 529/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 530/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7178
# Epoch 531/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 532/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 533/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 534/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7236
# Epoch 535/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 536/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 537/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7275
# Epoch 538/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 539/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 540/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 541/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7274
# Epoch 542/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 543/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7300
# Epoch 544/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7256
# Epoch 545/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 546/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 547/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 548/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 549/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 550/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 551/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 552/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 553/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 554/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 555/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 556/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 557/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 558/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 559/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 560/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 561/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 562/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 563/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 564/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 565/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 566/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7176
# Epoch 567/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 568/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 569/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 570/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7234
# Epoch 571/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7303
# Epoch 572/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 573/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7332
# Epoch 574/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 575/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 576/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 577/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 578/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 579/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 580/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 581/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 582/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7178
# Epoch 583/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 584/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 585/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 586/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7236
# Epoch 587/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 588/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 589/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 590/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 591/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 592/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 593/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7273
# Epoch 594/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 595/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7300
# Epoch 596/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7256
# Epoch 597/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 598/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 599/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 600/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 601/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 602/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 603/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 604/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 605/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 606/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 607/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 608/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 609/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 610/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 611/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 612/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 613/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 614/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 615/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 616/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 617/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 618/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 619/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 620/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 621/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 622/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 623/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 624/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 625/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 626/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7235
# Epoch 627/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7303
# Epoch 628/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 629/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7332
# Epoch 630/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 631/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7358
# Epoch 632/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 633/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 634/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 635/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 636/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 637/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 638/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7178
# Epoch 639/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 640/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 641/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 642/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7236
# Epoch 643/1000
#  - 1s - loss: 0.4601 - val_loss: 0.7304
# Epoch 644/1000
#  - 1s - loss: 0.4577 - val_loss: 0.7262
# Epoch 645/1000
#  - 1s - loss: 0.4589 - val_loss: 0.7274
# Epoch 646/1000
#  - 1s - loss: 0.4589 - val_loss: 0.7289
# Epoch 647/1000
#  - 1s - loss: 0.4577 - val_loss: 0.7245
# Epoch 648/1000
#  - 1s - loss: 0.4601 - val_loss: 0.7315
# Epoch 649/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7273
# Epoch 650/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 651/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7300
# Epoch 652/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7256
# Epoch 653/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 654/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 655/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 656/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 657/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 658/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 659/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 660/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 661/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 662/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 663/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 664/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 665/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 666/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 667/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 668/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 669/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 670/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 671/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 672/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 673/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 674/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7176
# Epoch 675/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 676/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 677/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 678/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7234
# Epoch 679/1000
#  - 0s - loss: 0.4602 - val_loss: 0.7303
# Epoch 680/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 681/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7332
# Epoch 682/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 683/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 684/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 685/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 686/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 687/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 688/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 689/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 690/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 691/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 692/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 693/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 694/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7235
# Epoch 695/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 696/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 697/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 698/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 699/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 700/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 701/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7273
# Epoch 702/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 703/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7300
# Epoch 704/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7256
# Epoch 705/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 706/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 707/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 708/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7198
# Epoch 709/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 710/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 711/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 712/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 713/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 714/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 715/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 716/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 717/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 718/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 719/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 720/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 721/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 722/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 723/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 724/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 725/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 726/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 727/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 728/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 729/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 730/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 731/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 732/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 733/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 734/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7235
# Epoch 735/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7303
# Epoch 736/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 737/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7332
# Epoch 738/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 739/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 740/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 741/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 742/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 743/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 744/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 745/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 746/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7178
# Epoch 747/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 748/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 749/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 750/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7236
# Epoch 751/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 752/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 753/1000
#  - 1s - loss: 0.4589 - val_loss: 0.7274
# Epoch 754/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 755/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 756/1000
#  - 1s - loss: 0.4601 - val_loss: 0.7315
# Epoch 757/1000
#  - 1s - loss: 0.4577 - val_loss: 0.7273
# Epoch 758/1000
#  - 1s - loss: 0.4589 - val_loss: 0.7285
# Epoch 759/1000
#  - 1s - loss: 0.4589 - val_loss: 0.7300
# Epoch 760/1000
#  - 1s - loss: 0.4577 - val_loss: 0.7256
# Epoch 761/1000
#  - 1s - loss: 0.4601 - val_loss: 0.7326
# Epoch 762/1000
#  - 1s - loss: 0.4565 - val_loss: 0.7226
# Epoch 763/1000
#  - 1s - loss: 0.4613 - val_loss: 0.7352
# Epoch 764/1000
#  - 1s - loss: 0.4553 - val_loss: 0.7199
# Epoch 765/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 766/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 767/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 768/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 769/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 770/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 771/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 772/1000
#  - 1s - loss: 0.4553 - val_loss: 0.7200
# Epoch 773/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 774/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 775/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 776/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 777/1000
#  - 1s - loss: 0.4625 - val_loss: 0.7382
# Epoch 778/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 779/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 780/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 781/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 782/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7176
# Epoch 783/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 784/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 785/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 786/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7234
# Epoch 787/1000
#  - 0s - loss: 0.4602 - val_loss: 0.7303
# Epoch 788/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 789/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7331
# Epoch 790/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 791/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 792/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 793/1000
#  - 1s - loss: 0.4625 - val_loss: 0.7383
# Epoch 794/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 795/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 796/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 797/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 798/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 799/1000
#  - 1s - loss: 0.4636 - val_loss: 0.7416
# Epoch 800/1000
#  - 1s - loss: 0.4537 - val_loss: 0.7204
# Epoch 801/1000
#  - 1s - loss: 0.4614 - val_loss: 0.7333
# Epoch 802/1000
#  - 1s - loss: 0.4565 - val_loss: 0.7235
# Epoch 803/1000
#  - 1s - loss: 0.4601 - val_loss: 0.7304
# Epoch 804/1000
#  - 1s - loss: 0.4577 - val_loss: 0.7262
# Epoch 805/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 806/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 807/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 808/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 809/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7273
# Epoch 810/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 811/1000
#  - 1s - loss: 0.4589 - val_loss: 0.7300
# Epoch 812/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7255
# Epoch 813/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 814/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 815/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 816/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7198
# Epoch 817/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 818/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 819/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 820/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 821/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 822/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 823/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 824/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 825/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 826/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 827/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 828/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 829/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 830/1000
#  - 1s - loss: 0.4548 - val_loss: 0.7226
# Epoch 831/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 832/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 833/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 834/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 835/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 836/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 837/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 838/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7176
# Epoch 839/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 840/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 841/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 842/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7234
# Epoch 843/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7303
# Epoch 844/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 845/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7332
# Epoch 846/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 847/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 848/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 849/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 850/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 851/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 852/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 853/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 854/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7178
# Epoch 855/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 856/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 857/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 858/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7236
# Epoch 859/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 860/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 861/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 862/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 863/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 864/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 865/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7273
# Epoch 866/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 867/1000
#  - 1s - loss: 0.4589 - val_loss: 0.7300
# Epoch 868/1000
#  - 1s - loss: 0.4577 - val_loss: 0.7256
# Epoch 869/1000
#  - 1s - loss: 0.4601 - val_loss: 0.7326
# Epoch 870/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 871/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 872/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 873/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 874/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 875/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 876/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 877/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 878/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 879/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 880/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 881/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 882/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 883/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 884/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 885/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 886/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 887/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 888/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 889/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 890/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 891/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 892/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 893/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 894/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 895/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 896/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 897/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 898/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7235
# Epoch 899/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7303
# Epoch 900/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 901/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7332
# Epoch 902/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 903/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7358
# Epoch 904/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 905/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 906/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 907/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 908/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 909/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 910/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7178
# Epoch 911/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 912/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 913/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 914/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7236
# Epoch 915/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 916/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 917/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 918/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 919/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 920/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 921/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7273
# Epoch 922/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 923/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7300
# Epoch 924/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7256
# Epoch 925/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 926/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 927/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 928/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 929/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 930/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 931/1000
#  - 1s - loss: 0.4613 - val_loss: 0.7356
# Epoch 932/1000
#  - 1s - loss: 0.4553 - val_loss: 0.7199
# Epoch 933/1000
#  - 1s - loss: 0.4625 - val_loss: 0.7381
# Epoch 934/1000
#  - 1s - loss: 0.4548 - val_loss: 0.7226
# Epoch 935/1000
#  - 1s - loss: 0.4613 - val_loss: 0.7356
# Epoch 936/1000
#  - 1s - loss: 0.4553 - val_loss: 0.7200
# Epoch 937/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 938/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 939/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 940/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 941/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 942/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 943/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 944/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Epoch 945/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7386
# Epoch 946/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7176
# Epoch 947/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7415
# Epoch 948/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7203
# Epoch 949/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7332
# Epoch 950/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7234
# Epoch 951/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7303
# Epoch 952/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7261
# Epoch 953/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7332
# Epoch 954/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7231
# Epoch 955/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7357
# Epoch 956/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7201
# Epoch 957/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7383
# Epoch 958/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7174
# Epoch 959/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7412
# Epoch 960/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7200
# Epoch 961/1000
#  - 0s - loss: 0.4624 - val_loss: 0.7387
# Epoch 962/1000
#  - 0s - loss: 0.4542 - val_loss: 0.7177
# Epoch 963/1000
#  - 0s - loss: 0.4636 - val_loss: 0.7416
# Epoch 964/1000
#  - 0s - loss: 0.4537 - val_loss: 0.7204
# Epoch 965/1000
#  - 0s - loss: 0.4614 - val_loss: 0.7333
# Epoch 966/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7235
# Epoch 967/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7304
# Epoch 968/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7262
# Epoch 969/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7274
# Epoch 970/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7289
# Epoch 971/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7245
# Epoch 972/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7315
# Epoch 973/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7273
# Epoch 974/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7285
# Epoch 975/1000
#  - 0s - loss: 0.4589 - val_loss: 0.7300
# Epoch 976/1000
#  - 0s - loss: 0.4577 - val_loss: 0.7256
# Epoch 977/1000
#  - 0s - loss: 0.4601 - val_loss: 0.7326
# Epoch 978/1000
#  - 0s - loss: 0.4565 - val_loss: 0.7226
# Epoch 979/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7352
# Epoch 980/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7198
# Epoch 981/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 982/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 983/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 984/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 985/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7381
# Epoch 986/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7225
# Epoch 987/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 988/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7199
# Epoch 989/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 990/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 991/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 992/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 993/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 994/1000
#  - 0s - loss: 0.4548 - val_loss: 0.7226
# Epoch 995/1000
#  - 0s - loss: 0.4613 - val_loss: 0.7356
# Epoch 996/1000
#  - 0s - loss: 0.4553 - val_loss: 0.7200
# Epoch 997/1000
#  - 0s - loss: 0.4625 - val_loss: 0.7382
# Epoch 998/1000
#  - 0s - loss: 0.4541 - val_loss: 0.7173
# Epoch 999/1000
#  - 0s - loss: 0.4637 - val_loss: 0.7411
# Epoch 1000/1000
#  - 0s - loss: 0.4536 - val_loss: 0.7199
# Results:
# Accuracy: 23.2978509741%
# Precision: 56.5652885743%
# Recall: 23.2978509741%
# FMeasure: 8.86777355806%

# %% [markdown]
# ### Prediction
# - Outliers not removed
# - Data not normalized
# - lagValue = 1
# - epochCount = 1000
# - batchSize = 50
# - lstmStackCount = 5

# %%
testID = 4
print "TestID: ", testID

resultsFilename = 'TestResults.txt'

predictor = LSTMPredictor(testID
                          , trainFilename='EEGEyeState_Training.arff.csv'
                          , testFilename='EEGEyeState_Testing.arff.csv')

lagValue = 1
predictor.CompileModel(lagCount=lagValue
               , neuronCount=50
               , dropOut=0.0
               , useLaggedOutput=True
               , modelArchitectureFilename='01_modelArchitecture'
               , lstmStackCount=5)

predictor.FitModel(epochCount=1000
           , batchSize=50
           , resultsFile=resultsFilename
           , lossFuncFilePrefix='01_lossFile'
           , predictionFilePrefix='01_predictionFile'
           , verbosity=2)
# Out:
# TestID:  4
# Train on 10000 samples, validate on 4979 samples
# Epoch 1/1000
#  - 3s - loss: 0.5739 - val_loss: 0.3148
# Epoch 2/1000
#  - 1s - loss: 0.5539 - val_loss: 0.3431
# Epoch 3/1000
#  - 1s - loss: 0.5477 - val_loss: 0.3905
# Epoch 4/1000
#  - 1s - loss: 0.5410 - val_loss: 0.4450
# Epoch 5/1000
#  - 1s - loss: 0.5347 - val_loss: 0.5152
# Epoch 6/1000
#  - 1s - loss: 0.5225 - val_loss: 0.5917
# Epoch 7/1000
#  - 1s - loss: 0.5100 - val_loss: 0.6906
# Epoch 8/1000
#  - 1s - loss: 0.4722 - val_loss: 0.6497
# Epoch 9/1000
#  - 1s - loss: 0.4947 - val_loss: 0.7387
# Epoch 10/1000
#  - 1s - loss: 0.4614 - val_loss: 0.6904
# Epoch 11/1000
#  - 1s - loss: 0.4743 - val_loss: 0.7030
# Epoch 12/1000
#  - 1s - loss: 0.4712 - val_loss: 0.7060
# Epoch 13/1000
#  - 1s - loss: 0.4684 - val_loss: 0.7012
# Epoch 14/1000
#  - 1s - loss: 0.4712 - val_loss: 0.7137
# Epoch 15/1000
#  - 1s - loss: 0.4656 - val_loss: 0.7020
# Epoch 16/1000
#  - 1s - loss: 0.4702 - val_loss: 0.7151
# Epoch 17/1000
#  - 1s - loss: 0.4647 - val_loss: 0.7041
# Epoch 18/1000
#  - 1s - loss: 0.4694 - val_loss: 0.7180
# Epoch 19/1000
#  - 1s - loss: 0.4642 - val_loss: 0.7077
# Epoch 20/1000
#  - 1s - loss: 0.4688 - val_loss: 0.7222
# Epoch 21/1000
#  - 1s - loss: 0.4620 - val_loss: 0.7054
# Epoch 22/1000
#  - 1s - loss: 0.4695 - val_loss: 0.7266
# Epoch 23/1000
#  - 1s - loss: 0.4602 - val_loss: 0.7039
# Epoch 24/1000
#  - 1s - loss: 0.4703 - val_loss: 0.7316
# Epoch 25/1000
#  - 2s - loss: 0.4586 - val_loss: 0.7097
# Epoch 26/1000
#  - 2s - loss: 0.4670 - val_loss: 0.7237
# Epoch 27/1000
#  - 1s - loss: 0.4614 - val_loss: 0.7102
# Epoch 28/1000
#  - 1s - loss: 0.4666 - val_loss: 0.7238
# Epoch 29/1000
#  - 1s - loss: 0.4606 - val_loss: 0.7091
# Epoch 30/1000
#  - 1s - loss: 0.4679 - val_loss: 0.7304
# Epoch 31/1000
#  - 1s - loss: 0.4576 - val_loss: 0.7040
# Epoch 32/1000
#  - 1s - loss: 0.4700 - val_loss: 0.7381
# Epoch 33/1000
#  - 1s - loss: 0.4564 - val_loss: 0.7111
# Epoch 34/1000
#  - 1s - loss: 0.4659 - val_loss: 0.7264
# Epoch 35/1000
#  - 1s - loss: 0.4602 - val_loss: 0.7138
# Epoch 36/1000
#  - 1s - loss: 0.4655 - val_loss: 0.7278
# Epoch 37/1000
#  - 1s - loss: 0.4599 - val_loss: 0.7150
# Epoch 38/1000
#  - 1s - loss: 0.4654 - val_loss: 0.7290
# Epoch 39/1000
#  - 2s - loss: 0.4583 - val_loss: 0.7101
# Epoch 40/1000
#  - 2s - loss: 0.4666 - val_loss: 0.7302
# Epoch 41/1000
#  - 2s - loss: 0.4584 - val_loss: 0.7122
# Epoch 42/1000
#  - 1s - loss: 0.4662 - val_loss: 0.7321
# Epoch 43/1000
#  - 1s - loss: 0.4575 - val_loss: 0.7140
# Epoch 44/1000
#  - 1s - loss: 0.4648 - val_loss: 0.7279
# Epoch 45/1000
#  - 1s - loss: 0.4594 - val_loss: 0.7157
# Epoch 46/1000
#  - 1s - loss: 0.4636 - val_loss: 0.7227
# Epoch 47/1000
#  - 1s - loss: 0.4608 - val_loss: 0.7177
# Epoch 48/1000
#  - 1s - loss: 0.4632 - val_loss: 0.7252
# Epoch 49/1000
#  - 1s - loss: 0.4604 - val_loss: 0.7199
# Epoch 50/1000
#  - 1s - loss: 0.4630 - val_loss: 0.7267
# Epoch 51/1000
#  - 1s - loss: 0.4604 - val_loss: 0.7209
# Epoch 52/1000
#  - 1s - loss: 0.4617 - val_loss: 0.7219
# Epoch 53/1000
#  - 2s - loss: 0.4616 - val_loss: 0.7229
# Epoch 54/1000
#  - 2s - loss: 0.4615 - val_loss: 0.7241
# Epoch 55/1000
#  - 2s - loss: 0.4614 - val_loss: 0.7248
# Epoch 56/1000
#  - 1s - loss: 0.4600 - val_loss: 0.7191
# Epoch 57/1000
#  - 1s - loss: 0.4627 - val_loss: 0.7265
# Epoch 58/1000
#  - 1s - loss: 0.4599 - val_loss: 0.7214
# Epoch 59/1000
#  - 1s - loss: 0.4624 - val_loss: 0.7282
# Epoch 60/1000
#  - 1s - loss: 0.4585 - val_loss: 0.7167
# Epoch 61/1000
#  - 1s - loss: 0.4637 - val_loss: 0.7295
# Epoch 62/1000
#  - 1s - loss: 0.4586 - val_loss: 0.7190
# Epoch 63/1000
#  - 1s - loss: 0.4634 - val_loss: 0.7319
# Epoch 64/1000
#  - 1s - loss: 0.4570 - val_loss: 0.7149
# Epoch 65/1000
#  - 1s - loss: 0.4645 - val_loss: 0.7330
# Epoch 66/1000
#  - 1s - loss: 0.4571 - val_loss: 0.7150
# Epoch 67/1000
#  - 1s - loss: 0.4637 - val_loss: 0.7288
# Epoch 68/1000
#  - 2s - loss: 0.4581 - val_loss: 0.7185
# Epoch 69/1000
#  - 2s - loss: 0.4629 - val_loss: 0.7310
# Epoch 70/1000
#  - 1s - loss: 0.4580 - val_loss: 0.7205
# Epoch 71/1000
#  - 1s - loss: 0.4628 - val_loss: 0.7324
# Epoch 72/1000
#  - 1s - loss: 0.4568 - val_loss: 0.7162
# Epoch 73/1000
#  - 1s - loss: 0.4640 - val_loss: 0.7343
# Epoch 74/1000
#  - 1s - loss: 0.4567 - val_loss: 0.7184
# Epoch 75/1000
#  - 1s - loss: 0.4637 - val_loss: 0.7362
# Epoch 76/1000
#  - 1s - loss: 0.4553 - val_loss: 0.7146
# Epoch 77/1000
#  - 1s - loss: 0.4650 - val_loss: 0.7380
# Epoch 78/1000
#  - 1s - loss: 0.4555 - val_loss: 0.7222
# Epoch 79/1000
#  - 1s - loss: 0.4611 - val_loss: 0.7295
# Epoch 80/1000
#  - 1s - loss: 0.4587 - val_loss: 0.7248
# Epoch 81/1000
#  - 1s - loss: 0.4610 - val_loss: 0.7314
# Epoch 82/1000
#  - 1s - loss: 0.4573 - val_loss: 0.7208
# Epoch 83/1000
#  - 1s - loss: 0.4621 - val_loss: 0.7330
# Epoch 84/1000
#  - 1s - loss: 0.4573 - val_loss: 0.7230
# Epoch 85/1000
#  - 1s - loss: 0.4619 - val_loss: 0.7347
# Epoch 86/1000
#  - 1s - loss: 0.4560 - val_loss: 0.7194
# Epoch 87/1000
#  - 1s - loss: 0.4628 - val_loss: 0.7366
# Epoch 88/1000
#  - 2s - loss: 0.4560 - val_loss: 0.7215
# Epoch 89/1000
#  - 1s - loss: 0.4626 - val_loss: 0.7386
# Epoch 90/1000
#  - 1s - loss: 0.4547 - val_loss: 0.7180
# Epoch 91/1000
#  - 1s - loss: 0.4637 - val_loss: 0.7405
# Epoch 92/1000
#  - 1s - loss: 0.4541 - val_loss: 0.7205
# Epoch 93/1000
#  - 1s - loss: 0.4623 - val_loss: 0.7379
# Epoch 94/1000
#  - 1s - loss: 0.4550 - val_loss: 0.7231
# Epoch 95/1000
#  - 1s - loss: 0.4611 - val_loss: 0.7350
# Epoch 96/1000
#  - 1s - loss: 0.4567 - val_loss: 0.7257
# Epoch 97/1000
#  - 1s - loss: 0.4610 - val_loss: 0.7374
# Epoch 98/1000
#  - 1s - loss: 0.4554 - val_loss: 0.7227
# Epoch 99/1000
#  - 1s - loss: 0.4619 - val_loss: 0.7393
# Epoch 100/1000
#  - 1s - loss: 0.4542 - val_loss: 0.7200
# Epoch 101/1000
#  - 1s - loss: 0.4629 - val_loss: 0.7415
# Epoch 102/1000
#  - 1s - loss: 0.4537 - val_loss: 0.7223
# Epoch 103/1000
#  - 1s - loss: 0.4616 - val_loss: 0.7391
# Epoch 104/1000
#  - 1s - loss: 0.4540 - val_loss: 0.7202
# Epoch 105/1000
#  - 1s - loss: 0.4626 - val_loss: 0.7415
# Epoch 106/1000
#  - 1s - loss: 0.4541 - val_loss: 0.7276
# Epoch 107/1000
#  - 1s - loss: 0.4592 - val_loss: 0.7342
# Epoch 108/1000
#  - 1s - loss: 0.4572 - val_loss: 0.7304
# Epoch 109/1000
#  - 1s - loss: 0.4581 - val_loss: 0.7315
# Epoch 110/1000
#  - 1s - loss: 0.4580 - val_loss: 0.7327
# Epoch 111/1000
#  - 1s - loss: 0.4580 - val_loss: 0.7339
# Epoch 112/1000
#  - 1s - loss: 0.4568 - val_loss: 0.7299
# Epoch 113/1000
#  - 1s - loss: 0.4589 - val_loss: 0.7359
# Epoch 114/1000
#  - 1s - loss: 0.4557 - val_loss: 0.7271
# Epoch 115/1000
#  - 1s - loss: 0.4598 - val_loss: 0.7381
# Epoch 116/1000
#  - 1s - loss: 0.4545 - val_loss: 0.7250
# Epoch 117/1000
#  - 1s - loss: 0.4606 - val_loss: 0.7405
# Epoch 118/1000
#  - 1s - loss: 0.4540 - val_loss: 0.7275
# Epoch 119/1000
#  - 2s - loss: 0.4595 - val_loss: 0.7386
# Epoch 120/1000
#  - 1s - loss: 0.4544 - val_loss: 0.7257
# Epoch 121/1000
#  - 1s - loss: 0.4604 - val_loss: 0.7412
# Epoch 122/1000
#  - 1s - loss: 0.4533 - val_loss: 0.7239
# Epoch 123/1000
#  - 1s - loss: 0.4612 - val_loss: 0.7438
# Epoch 124/1000
#  - 1s - loss: 0.4528 - val_loss: 0.7266
# Epoch 125/1000
#  - 1s - loss: 0.4600 - val_loss: 0.7422
# Epoch 126/1000
#  - 1s - loss: 0.4532 - val_loss: 0.7252
# Epoch 127/1000
#  - 1s - loss: 0.4609 - val_loss: 0.7450
# Epoch 128/1000
#  - 1s - loss: 0.4527 - val_loss: 0.7280
# Epoch 129/1000
#  - 1s - loss: 0.4598 - val_loss: 0.7435
# Epoch 130/1000
#  - 1s - loss: 0.4531 - val_loss: 0.7265
# Epoch 131/1000
#  - 1s - loss: 0.4606 - val_loss: 0.7459
# Epoch 132/1000
#  - 1s - loss: 0.4521 - val_loss: 0.7248
# Epoch 133/1000
#  - 1s - loss: 0.4606 - val_loss: 0.7440
# Epoch 134/1000
#  - 1s - loss: 0.4530 - val_loss: 0.7320
# Epoch 135/1000
#  - 1s - loss: 0.4576 - val_loss: 0.7384
# Epoch 136/1000
#  - 1s - loss: 0.4547 - val_loss: 0.7308
# Epoch 137/1000
#  - 1s - loss: 0.4584 - val_loss: 0.7410
# Epoch 138/1000
#  - 1s - loss: 0.4537 - val_loss: 0.7290
# Epoch 139/1000
#  - 1s - loss: 0.4593 - val_loss: 0.7436
# Epoch 140/1000
#  - 1s - loss: 0.4527 - val_loss: 0.7275
# Epoch 141/1000
#  - 1s - loss: 0.4600 - val_loss: 0.7464
# Epoch 142/1000
#  - 1s - loss: 0.4518 - val_loss: 0.7260
# Epoch 143/1000
#  - 1s - loss: 0.4608 - val_loss: 0.7492
# Epoch 144/1000
#  - 1s - loss: 0.4521 - val_loss: 0.7372
# Epoch 145/1000
#  - 1s - loss: 0.4553 - val_loss: 0.7351
# Epoch 146/1000
#  - 1s - loss: 0.4562 - val_loss: 0.7364
# Epoch 147/1000
#  - 1s - loss: 0.4562 - val_loss: 0.7379
# Epoch 148/1000
#  - 1s - loss: 0.4552 - val_loss: 0.7348
# Epoch 149/1000
#  - 1s - loss: 0.4570 - val_loss: 0.7404
# Epoch 150/1000
#  - 1s - loss: 0.4542 - val_loss: 0.7330
# Epoch 151/1000
#  - 1s - loss: 0.4577 - val_loss: 0.7428
# Epoch 152/1000
#  - 1s - loss: 0.4533 - val_loss: 0.7313
# Epoch 153/1000
#  - 1s - loss: 0.4585 - val_loss: 0.7454
# Epoch 154/1000
#  - 1s - loss: 0.4523 - val_loss: 0.7298
# Epoch 155/1000
#  - 1s - loss: 0.4592 - val_loss: 0.7479
# Epoch 156/1000
#  - 1s - loss: 0.4520 - val_loss: 0.7365
# Epoch 157/1000
#  - 1s - loss: 0.4557 - val_loss: 0.7385
# Epoch 158/1000
#  - 1s - loss: 0.4548 - val_loss: 0.7356
# Epoch 159/1000
#  - 1s - loss: 0.4565 - val_loss: 0.7411
# Epoch 160/1000
#  - 1s - loss: 0.4538 - val_loss: 0.7341
# Epoch 161/1000
#  - 1s - loss: 0.4572 - val_loss: 0.7436
# Epoch 162/1000
#  - 1s - loss: 0.4529 - val_loss: 0.7326
# Epoch 163/1000
#  - 1s - loss: 0.4579 - val_loss: 0.7459
# Epoch 164/1000
#  - 1s - loss: 0.4520 - val_loss: 0.7312
# Epoch 165/1000
#  - 1s - loss: 0.4579 - val_loss: 0.7444
# Epoch 166/1000
#  - 1s - loss: 0.4528 - val_loss: 0.7338
# Epoch 167/1000
#  - 1s - loss: 0.4569 - val_loss: 0.7430
# Epoch 168/1000
#  - 1s - loss: 0.4526 - val_loss: 0.7326
# Epoch 169/1000
#  - 1s - loss: 0.4576 - val_loss: 0.7458
# Epoch 170/1000
#  - 1s - loss: 0.4518 - val_loss: 0.7314
# Epoch 171/1000
#  - 1s - loss: 0.4584 - val_loss: 0.7486
# Epoch 172/1000
#  - 1s - loss: 0.4510 - val_loss: 0.7306
# Epoch 173/1000
#  - 1s - loss: 0.4583 - val_loss: 0.7474
# Epoch 174/1000
#  - 1s - loss: 0.4512 - val_loss: 0.7333
# Epoch 175/1000
#  - 1s - loss: 0.4573 - val_loss: 0.7466
# Epoch 176/1000
#  - 1s - loss: 0.4516 - val_loss: 0.7326
# Epoch 177/1000
#  - 1s - loss: 0.4580 - val_loss: 0.7495
# Epoch 178/1000
#  - 1s - loss: 0.4513 - val_loss: 0.7392
# Epoch 179/1000
#  - 1s - loss: 0.4547 - val_loss: 0.7414
# Epoch 180/1000
#  - 1s - loss: 0.4538 - val_loss: 0.7388
# Epoch 181/1000
#  - 1s - loss: 0.4554 - val_loss: 0.7440
# Epoch 182/1000
#  - 1s - loss: 0.4530 - val_loss: 0.7377
# Epoch 183/1000
#  - 1s - loss: 0.4554 - val_loss: 0.7428
# Epoch 184/1000
#  - 1s - loss: 0.4529 - val_loss: 0.7366
# Epoch 185/1000
#  - 1s - loss: 0.4560 - val_loss: 0.7455
# Epoch 186/1000
#  - 1s - loss: 0.4521 - val_loss: 0.7357
# Epoch 187/1000
#  - 1s - loss: 0.4567 - val_loss: 0.7482
# Epoch 188/1000
#  - 1s - loss: 0.4513 - val_loss: 0.7348
# Epoch 189/1000
#  - 1s - loss: 0.4566 - val_loss: 0.7470
# Epoch 190/1000
#  - 2s - loss: 0.4511 - val_loss: 0.7337
# Epoch 191/1000
#  - 2s - loss: 0.4573 - val_loss: 0.7499
# Epoch 192/1000
#  - 1s - loss: 0.4504 - val_loss: 0.7334
# Epoch 193/1000
#  - 1s - loss: 0.4572 - val_loss: 0.7490
# Epoch 194/1000
#  - 1s - loss: 0.4507 - val_loss: 0.7361
# Epoch 195/1000
#  - 1s - loss: 0.4563 - val_loss: 0.7486
# Epoch 196/1000
#  - 1s - loss: 0.4510 - val_loss: 0.7355
# Epoch 197/1000
#  - 1s - loss: 0.4563 - val_loss: 0.7476
# Epoch 198/1000
#  - 1s - loss: 0.4509 - val_loss: 0.7349
# Epoch 199/1000
#  - 1s - loss: 0.4569 - val_loss: 0.7505
# Epoch 200/1000
#  - 1s - loss: 0.4502 - val_loss: 0.7343
# Epoch 201/1000
#  - 1s - loss: 0.4569 - val_loss: 0.7498
# Epoch 202/1000
#  - 1s - loss: 0.4505 - val_loss: 0.7373
# Epoch 203/1000
#  - 1s - loss: 0.4559 - val_loss: 0.7496
# Epoch 204/1000
#  - 1s - loss: 0.4508 - val_loss: 0.7404
# Epoch 205/1000
#  - 1s - loss: 0.4544 - val_loss: 0.7458
# Epoch 206/1000
#  - 1s - loss: 0.4522 - val_loss: 0.7402
# Epoch 207/1000
#  - 1s - loss: 0.4543 - val_loss: 0.7450
# Epoch 208/1000
#  - 1s - loss: 0.4521 - val_loss: 0.7396
# Epoch 209/1000
#  - 1s - loss: 0.4549 - val_loss: 0.7479
# Epoch 210/1000
#  - 1s - loss: 0.4514 - val_loss: 0.7391
# Epoch 211/1000
#  - 1s - loss: 0.4549 - val_loss: 0.7472
# Epoch 212/1000
#  - 1s - loss: 0.4512 - val_loss: 0.7384
# Epoch 213/1000
#  - 1s - loss: 0.4555 - val_loss: 0.7500
# Epoch 214/1000
#  - 1s - loss: 0.4506 - val_loss: 0.7413
# Epoch 215/1000
#  - 1s - loss: 0.4540 - val_loss: 0.7466
# Epoch 216/1000
#  - 1s - loss: 0.4519 - val_loss: 0.7411
# Epoch 217/1000
#  - 1s - loss: 0.4540 - val_loss: 0.7460
# Epoch 218/1000
#  - 1s - loss: 0.4518 - val_loss: 0.7404
# Epoch 219/1000
#  - 1s - loss: 0.4546 - val_loss: 0.7488
# Epoch 220/1000
#  - 1s - loss: 0.4511 - val_loss: 0.7404
# Epoch 221/1000
#  - 1s - loss: 0.4545 - val_loss: 0.7482
# Epoch 222/1000
#  - 1s - loss: 0.4510 - val_loss: 0.7399
# Epoch 223/1000
#  - 1s - loss: 0.4544 - val_loss: 0.7477
# Epoch 224/1000
#  - 1s - loss: 0.4509 - val_loss: 0.7394
# Epoch 225/1000
#  - 1s - loss: 0.4550 - val_loss: 0.7506
# Epoch 226/1000
#  - 1s - loss: 0.4503 - val_loss: 0.7392
# Epoch 227/1000
#  - 1s - loss: 0.4549 - val_loss: 0.7501
# Epoch 228/1000
#  - 1s - loss: 0.4502 - val_loss: 0.7388
# Epoch 229/1000
#  - 1s - loss: 0.4549 - val_loss: 0.7498
# Epoch 230/1000
#  - 1s - loss: 0.4501 - val_loss: 0.7388
# Epoch 231/1000
#  - 1s - loss: 0.4554 - val_loss: 0.7529
# Epoch 232/1000
#  - 1s - loss: 0.4495 - val_loss: 0.7416
# Epoch 233/1000
#  - 1s - loss: 0.4540 - val_loss: 0.7499
# Epoch 234/1000
#  - 1s - loss: 0.4500 - val_loss: 0.7389
# Epoch 235/1000
#  - 1s - loss: 0.4552 - val_loss: 0.7528
# Epoch 236/1000
#  - 1s - loss: 0.4499 - val_loss: 0.7448
# Epoch 237/1000
#  - 1s - loss: 0.4526 - val_loss: 0.7469
# Epoch 238/1000
#  - 1s - loss: 0.4519 - val_loss: 0.7452
# Epoch 239/1000
#  - 1s - loss: 0.4520 - val_loss: 0.7435
# Epoch 240/1000
#  - 1s - loss: 0.4532 - val_loss: 0.7480
# Epoch 241/1000
#  - 1s - loss: 0.4512 - val_loss: 0.7432
# Epoch 242/1000
#  - 1s - loss: 0.4531 - val_loss: 0.7476
# Epoch 243/1000
#  - 1s - loss: 0.4511 - val_loss: 0.7430
# Epoch 244/1000
#  - 1s - loss: 0.4531 - val_loss: 0.7474
# Epoch 245/1000
#  - 1s - loss: 0.4511 - val_loss: 0.7427
# Epoch 246/1000
#  - 1s - loss: 0.4536 - val_loss: 0.7503
# Epoch 247/1000
#  - 1s - loss: 0.4505 - val_loss: 0.7426
# Epoch 248/1000
#  - 1s - loss: 0.4535 - val_loss: 0.7499
# Epoch 249/1000
#  - 1s - loss: 0.4504 - val_loss: 0.7423
# Epoch 250/1000
#  - 1s - loss: 0.4535 - val_loss: 0.7497
# Epoch 251/1000
#  - 1s - loss: 0.4504 - val_loss: 0.7421
# Epoch 252/1000
#  - 1s - loss: 0.4540 - val_loss: 0.7524
# Epoch 253/1000
#  - 1s - loss: 0.4495 - val_loss: 0.7420
# Epoch 254/1000
#  - 1s - loss: 0.4540 - val_loss: 0.7524
# Epoch 255/1000
#  - 1s - loss: 0.4493 - val_loss: 0.7420
# Epoch 256/1000
#  - 1s - loss: 0.4531 - val_loss: 0.7474
# Epoch 257/1000
#  - 1s - loss: 0.4515 - val_loss: 0.7455
# Epoch 258/1000
#  - 1s - loss: 0.4521 - val_loss: 0.7467
# Epoch 259/1000
#  - 1s - loss: 0.4514 - val_loss: 0.7450
# Epoch 260/1000
#  - 1s - loss: 0.4526 - val_loss: 0.7493
# Epoch 261/1000
#  - 1s - loss: 0.4507 - val_loss: 0.7444
# Epoch 262/1000
#  - 1s - loss: 0.4526 - val_loss: 0.7489
# Epoch 263/1000
#  - 1s - loss: 0.4507 - val_loss: 0.7444
# Epoch 264/1000
#  - 1s - loss: 0.4525 - val_loss: 0.7486
# Epoch 265/1000
#  - 1s - loss: 0.4506 - val_loss: 0.7442
# Epoch 266/1000
#  - 1s - loss: 0.4530 - val_loss: 0.7512
# Epoch 267/1000
#  - 1s - loss: 0.4500 - val_loss: 0.7441
# Epoch 268/1000
#  - 1s - loss: 0.4529 - val_loss: 0.7509
# Epoch 269/1000
#  - 1s - loss: 0.4499 - val_loss: 0.7438
# Epoch 270/1000
#  - 1s - loss: 0.4529 - val_loss: 0.7506
# Epoch 271/1000
#  - 1s - loss: 0.4499 - val_loss: 0.7437
# Epoch 272/1000
#  - 1s - loss: 0.4533 - val_loss: 0.7533
# Epoch 273/1000
#  - 1s - loss: 0.4490 - val_loss: 0.7435
# Epoch 274/1000
#  - 1s - loss: 0.4533 - val_loss: 0.7533
# Epoch 275/1000
#  - 1s - loss: 0.4493 - val_loss: 0.7462
# Epoch 276/1000
#  - 1s - loss: 0.4521 - val_loss: 0.7508
# Epoch 277/1000
#  - 1s - loss: 0.4497 - val_loss: 0.7440
# Epoch 278/1000
#  - 1s - loss: 0.4531 - val_loss: 0.7534
# Epoch 279/1000
#  - 1s - loss: 0.4490 - val_loss: 0.7440
# Epoch 280/1000
#  - 1s - loss: 0.4531 - val_loss: 0.7535
# Epoch 281/1000
#  - 1s - loss: 0.4491 - val_loss: 0.7440
# Epoch 282/1000
#  - 2s - loss: 0.4530 - val_loss: 0.7533
# Epoch 283/1000
#  - 2s - loss: 0.4491 - val_loss: 0.7439
# Epoch 284/1000
#  - 1s - loss: 0.4529 - val_loss: 0.7531
# Epoch 285/1000
#  - 1s - loss: 0.4490 - val_loss: 0.7439
# Epoch 286/1000
#  - 1s - loss: 0.4529 - val_loss: 0.7531
# Epoch 287/1000
#  - 1s - loss: 0.4490 - val_loss: 0.7441
# Epoch 288/1000
#  - 1s - loss: 0.4528 - val_loss: 0.7530
# Epoch 289/1000
#  - 1s - loss: 0.4489 - val_loss: 0.7441
# Epoch 290/1000
#  - 1s - loss: 0.4532 - val_loss: 0.7557
# Epoch 291/1000
#  - 1s - loss: 0.4484 - val_loss: 0.7467
# Epoch 292/1000
#  - 1s - loss: 0.4516 - val_loss: 0.7508
# Epoch 293/1000
#  - 1s - loss: 0.4496 - val_loss: 0.7446
# Epoch 294/1000
#  - 1s - loss: 0.4526 - val_loss: 0.7532
# Epoch 295/1000
#  - 1s - loss: 0.4488 - val_loss: 0.7446
# Epoch 296/1000
#  - 1s - loss: 0.4526 - val_loss: 0.7532
# Epoch 297/1000
#  - 1s - loss: 0.4488 - val_loss: 0.7446
# Epoch 298/1000
#  - 1s - loss: 0.4529 - val_loss: 0.7559
# Epoch 299/1000
#  - 1s - loss: 0.4483 - val_loss: 0.7472
# Epoch 300/1000
#  - 1s - loss: 0.4513 - val_loss: 0.7512
# Epoch 301/1000
#  - 1s - loss: 0.4497 - val_loss: 0.7476
# Epoch 302/1000
#  - 1s - loss: 0.4513 - val_loss: 0.7512
# Epoch 303/1000
#  - 1s - loss: 0.4496 - val_loss: 0.7476
# Epoch 304/1000
#  - 1s - loss: 0.4517 - val_loss: 0.7537
# Epoch 305/1000
#  - 1s - loss: 0.4488 - val_loss: 0.7477
# Epoch 306/1000
#  - 1s - loss: 0.4516 - val_loss: 0.7540
# Epoch 307/1000
#  - 1s - loss: 0.4485 - val_loss: 0.7457
# Epoch 308/1000
#  - 1s - loss: 0.4525 - val_loss: 0.7564
# Epoch 309/1000
#  - 1s - loss: 0.4481 - val_loss: 0.7482
# Epoch 310/1000
#  - 1s - loss: 0.4510 - val_loss: 0.7521
# Epoch 311/1000
#  - 1s - loss: 0.4494 - val_loss: 0.7483
# Epoch 312/1000
#  - 1s - loss: 0.4510 - val_loss: 0.7521
# Epoch 313/1000
#  - 1s - loss: 0.4494 - val_loss: 0.7488
# Epoch 314/1000
#  - 1s - loss: 0.4508 - val_loss: 0.7524
# Epoch 315/1000
#  - 1s - loss: 0.4493 - val_loss: 0.7490
# Epoch 316/1000
#  - 1s - loss: 0.4508 - val_loss: 0.7525
# Epoch 317/1000
#  - 1s - loss: 0.4493 - val_loss: 0.7493
# Epoch 318/1000
#  - 1s - loss: 0.4503 - val_loss: 0.7505
# Epoch 319/1000
#  - 1s - loss: 0.4502 - val_loss: 0.7518
# Epoch 320/1000
#  - 1s - loss: 0.4493 - val_loss: 0.7485
# Epoch 321/1000
#  - 1s - loss: 0.4512 - val_loss: 0.7543
# Epoch 322/1000
#  - 1s - loss: 0.4483 - val_loss: 0.7467
# Epoch 323/1000
#  - 1s - loss: 0.4516 - val_loss: 0.7547
# Epoch 324/1000
#  - 1s - loss: 0.4482 - val_loss: 0.7471
# Epoch 325/1000
#  - 1s - loss: 0.4519 - val_loss: 0.7572
# Epoch 326/1000
#  - 1s - loss: 0.4478 - val_loss: 0.7496
# Epoch 327/1000
#  - 1s - loss: 0.4501 - val_loss: 0.7513
# Epoch 328/1000
#  - 1s - loss: 0.4500 - val_loss: 0.7525
# Epoch 329/1000
#  - 1s - loss: 0.4495 - val_loss: 0.7515
# Epoch 330/1000
#  - 1s - loss: 0.4499 - val_loss: 0.7527
# Epoch 331/1000
#  - 1s - loss: 0.4494 - val_loss: 0.7518
# Epoch 332/1000
#  - 1s - loss: 0.4499 - val_loss: 0.7530
# Epoch 333/1000
#  - 1s - loss: 0.4494 - val_loss: 0.7521
# Epoch 334/1000
#  - 1s - loss: 0.4498 - val_loss: 0.7533
# Epoch 335/1000
#  - 1s - loss: 0.4489 - val_loss: 0.7502
# Epoch 336/1000
#  - 1s - loss: 0.4502 - val_loss: 0.7536
# Epoch 337/1000
#  - 1s - loss: 0.4488 - val_loss: 0.7506
# Epoch 338/1000
#  - 1s - loss: 0.4502 - val_loss: 0.7539
# Epoch 339/1000
#  - 1s - loss: 0.4485 - val_loss: 0.7490
# Epoch 340/1000
#  - 1s - loss: 0.4510 - val_loss: 0.7563
# Epoch 341/1000
#  - 1s - loss: 0.4479 - val_loss: 0.7493
# Epoch 342/1000
#  - 1s - loss: 0.4503 - val_loss: 0.7528
# Epoch 343/1000
#  - 1s - loss: 0.4492 - val_loss: 0.7518
# Epoch 344/1000
#  - 1s - loss: 0.4496 - val_loss: 0.7529
# Epoch 345/1000
#  - 1s - loss: 0.4491 - val_loss: 0.7521
# Epoch 346/1000
#  - 1s - loss: 0.4495 - val_loss: 0.7533
# Epoch 347/1000
#  - 1s - loss: 0.4488 - val_loss: 0.7506
# Epoch 348/1000
#  - 1s - loss: 0.4504 - val_loss: 0.7558
# Epoch 349/1000
#  - 1s - loss: 0.4482 - val_loss: 0.7508
# Epoch 350/1000
#  - 2s - loss: 0.4499 - val_loss: 0.7540
# Epoch 351/1000
#  - 1s - loss: 0.4483 - val_loss: 0.7495
# Epoch 352/1000
#  - 1s - loss: 0.4506 - val_loss: 0.7564
# Epoch 353/1000
#  - 1s - loss: 0.4477 - val_loss: 0.7498
# Epoch 354/1000
#  - 1s - loss: 0.4505 - val_loss: 0.7568
# Epoch 355/1000
#  - 2s - loss: 0.4476 - val_loss: 0.7503
# Epoch 356/1000
#  - 1s - loss: 0.4504 - val_loss: 0.7572
# Epoch 357/1000
#  - 1s - loss: 0.4476 - val_loss: 0.7507
# Epoch 358/1000
#  - 1s - loss: 0.4504 - val_loss: 0.7576
# Epoch 359/1000
#  - 1s - loss: 0.4473 - val_loss: 0.7512
# Epoch 360/1000
#  - 1s - loss: 0.4499 - val_loss: 0.7562
# Epoch 361/1000
#  - 1s - loss: 0.4479 - val_loss: 0.7518
# Epoch 362/1000
#  - 1s - loss: 0.4498 - val_loss: 0.7567
# Epoch 363/1000
#  - 1s - loss: 0.4477 - val_loss: 0.7523
# Epoch 364/1000
#  - 1s - loss: 0.4494 - val_loss: 0.7554
# Epoch 365/1000
#  - 1s - loss: 0.4482 - val_loss: 0.7530
# Epoch 366/1000
#  - 1s - loss: 0.4493 - val_loss: 0.7560
# Epoch 367/1000
#  - 1s - loss: 0.4481 - val_loss: 0.7535
# Epoch 368/1000
#  - 1s - loss: 0.4492 - val_loss: 0.7565
# Epoch 369/1000
#  - 1s - loss: 0.4477 - val_loss: 0.7522
# Epoch 370/1000
#  - 1s - loss: 0.4496 - val_loss: 0.7570
# Epoch 371/1000
#  - 1s - loss: 0.4474 - val_loss: 0.7508
# Epoch 372/1000
#  - 1s - loss: 0.4503 - val_loss: 0.7594
# Epoch 373/1000
#  - 1s - loss: 0.4469 - val_loss: 0.7533
# Epoch 374/1000
#  - 2s - loss: 0.4492 - val_loss: 0.7567
# Epoch 375/1000
#  - 3s - loss: 0.4476 - val_loss: 0.7527
# Epoch 376/1000
#  - 2s - loss: 0.4494 - val_loss: 0.7573
# Epoch 377/1000
#  - 2s - loss: 0.4475 - val_loss: 0.7533
# Epoch 378/1000
#  - 1s - loss: 0.4493 - val_loss: 0.7580
# Epoch 379/1000
#  - 2s - loss: 0.4471 - val_loss: 0.7525
# Epoch 380/1000
#  - 2s - loss: 0.4496 - val_loss: 0.7588
# Epoch 381/1000
#  - 1s - loss: 0.4469 - val_loss: 0.7533
# Epoch 382/1000
#  - 1s - loss: 0.4492 - val_loss: 0.7580
# Epoch 383/1000
#  - 1s - loss: 0.4471 - val_loss: 0.7527
# Epoch 384/1000
#  - 1s - loss: 0.4495 - val_loss: 0.7589
# Epoch 385/1000
#  - 1s - loss: 0.4469 - val_loss: 0.7536
# Epoch 386/1000
#  - 1s - loss: 0.4491 - val_loss: 0.7582
# Epoch 387/1000
#  - 1s - loss: 0.4470 - val_loss: 0.7530
# Epoch 388/1000
#  - 1s - loss: 0.4494 - val_loss: 0.7592
# Epoch 389/1000
#  - 2s - loss: 0.4468 - val_loss: 0.7540
# Epoch 390/1000
#  - 2s - loss: 0.4490 - val_loss: 0.7586
# Epoch 391/1000
#  - 2s - loss: 0.4469 - val_loss: 0.7533
# Epoch 392/1000
#  - 2s - loss: 0.4493 - val_loss: 0.7594
# Epoch 393/1000
#  - 1s - loss: 0.4468 - val_loss: 0.7558
# Epoch 394/1000
#  - 1s - loss: 0.4479 - val_loss: 0.7558
# Epoch 395/1000
#  - 1s - loss: 0.4482 - val_loss: 0.7571
# Epoch 396/1000
#  - 1s - loss: 0.4475 - val_loss: 0.7551
# Epoch 397/1000
#  - 1s - loss: 0.4478 - val_loss: 0.7536
# Epoch 398/1000
#  - 1s - loss: 0.4490 - val_loss: 0.7578
# Epoch 399/1000
#  - 1s - loss: 0.4469 - val_loss: 0.7529
# Epoch 400/1000
#  - 1s - loss: 0.4495 - val_loss: 0.7603
# Epoch 401/1000
#  - 2s - loss: 0.4465 - val_loss: 0.7553
# Epoch 402/1000
#  - 1s - loss: 0.4481 - val_loss: 0.7567
# Epoch 403/1000
#  - 2s - loss: 0.4478 - val_loss: 0.7565
# Epoch 404/1000
#  - 1s - loss: 0.4477 - val_loss: 0.7562
# Epoch 405/1000
#  - 2s - loss: 0.4478 - val_loss: 0.7560
# Epoch 406/1000
#  - 2s - loss: 0.4480 - val_loss: 0.7572
# Epoch 407/1000
#  - 2s - loss: 0.4474 - val_loss: 0.7554
# Epoch 408/1000
#  - 2s - loss: 0.4483 - val_loss: 0.7582
# Epoch 409/1000
#  - 1s - loss: 0.4470 - val_loss: 0.7550
# Epoch 410/1000
#  - 1s - loss: 0.4482 - val_loss: 0.7565
# Epoch 411/1000
#  - 1s - loss: 0.4480 - val_loss: 0.7576
# Epoch 412/1000
#  - 1s - loss: 0.4473 - val_loss: 0.7557
# Epoch 413/1000
#  - 1s - loss: 0.4483 - val_loss: 0.7586
# Epoch 414/1000
#  - 1s - loss: 0.4470 - val_loss: 0.7554
# Epoch 415/1000
#  - 1s - loss: 0.4482 - val_loss: 0.7581
# Epoch 416/1000
#  - 2s - loss: 0.4470 - val_loss: 0.7550
# Epoch 417/1000
#  - 1s - loss: 0.4485 - val_loss: 0.7591
# Epoch 418/1000
#  - 1s - loss: 0.4466 - val_loss: 0.7547
# Epoch 419/1000
#  - 1s - loss: 0.4487 - val_loss: 0.7603
# Epoch 420/1000
#  - 1s - loss: 0.4463 - val_loss: 0.7557
# Epoch 421/1000
#  - 1s - loss: 0.4479 - val_loss: 0.7572
# Epoch 422/1000
#  - 2s - loss: 0.4475 - val_loss: 0.7571
# Epoch 423/1000
#  - 3s - loss: 0.4475 - val_loss: 0.7569
# Epoch 424/1000
#  - 2s - loss: 0.4475 - val_loss: 0.7568
# Epoch 425/1000
#  - 2s - loss: 0.4476 - val_loss: 0.7567
# Epoch 426/1000
#  - 1s - loss: 0.4478 - val_loss: 0.7579
# Epoch 427/1000
#  - 1s - loss: 0.4471 - val_loss: 0.7563
# Epoch 428/1000
#  - 1s - loss: 0.4480 - val_loss: 0.7590
# Epoch 429/1000
#  - 1s - loss: 0.4468 - val_loss: 0.7561
# Epoch 430/1000
#  - 1s - loss: 0.4480 - val_loss: 0.7587
# Epoch 431/1000
#  - 1s - loss: 0.4468 - val_loss: 0.7557
# Epoch 432/1000
#  - 1s - loss: 0.4483 - val_loss: 0.7599
# Epoch 433/1000
#  - 1s - loss: 0.4465 - val_loss: 0.7556
# Epoch 434/1000
#  - 2s - loss: 0.4482 - val_loss: 0.7596
# Epoch 435/1000
#  - 3s - loss: 0.4463 - val_loss: 0.7541
# Epoch 436/1000
#  - 2s - loss: 0.4488 - val_loss: 0.7608
# Epoch 437/1000
#  - 2s - loss: 0.4462 - val_loss: 0.7566
# Epoch 438/1000
#  - 1s - loss: 0.4476 - val_loss: 0.7580
# Epoch 439/1000
#  - 1s - loss: 0.4473 - val_loss: 0.7578
# Epoch 440/1000
#  - 1s - loss: 0.4469 - val_loss: 0.7552
# Epoch 441/1000
#  - 1s - loss: 0.4483 - val_loss: 0.7593
# Epoch 442/1000
#  - 1s - loss: 0.4467 - val_loss: 0.7565
# Epoch 443/1000
#  - 1s - loss: 0.4479 - val_loss: 0.7589
# Epoch 444/1000
#  - 1s - loss: 0.4466 - val_loss: 0.7564
# Epoch 445/1000
#  - 1s - loss: 0.4478 - val_loss: 0.7591
# Epoch 446/1000
#  - 2s - loss: 0.4467 - val_loss: 0.7563
# Epoch 447/1000
#  - 1s - loss: 0.4481 - val_loss: 0.7602
# Epoch 448/1000
#  - 1s - loss: 0.4462 - val_loss: 0.7561
# Epoch 449/1000
#  - 2s - loss: 0.4480 - val_loss: 0.7602
# Epoch 450/1000
#  - 2s - loss: 0.4464 - val_loss: 0.7562
# Epoch 451/1000
#  - 2s - loss: 0.4480 - val_loss: 0.7600
# Epoch 452/1000
#  - 1s - loss: 0.4463 - val_loss: 0.7561
# Epoch 453/1000
#  - 1s - loss: 0.4480 - val_loss: 0.7600
# Epoch 454/1000
#  - 1s - loss: 0.4463 - val_loss: 0.7561
# Epoch 455/1000
#  - 1s - loss: 0.4480 - val_loss: 0.7600
# Epoch 456/1000
#  - 1s - loss: 0.4463 - val_loss: 0.7561
# Epoch 457/1000
#  - 2s - loss: 0.4480 - val_loss: 0.7600
# Epoch 458/1000
#  - 1s - loss: 0.4463 - val_loss: 0.7561
# Epoch 459/1000
#  - 2s - loss: 0.4480 - val_loss: 0.7599
# Epoch 460/1000
