# %%
# Module imports
import seaborn as sns
from pandas import DataFrame, concat, Series
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
path = 'EEGEyeState_Training.arff.csv'
path_test = 'EEGEyeState_Testing.arff.csv'
lag = 0
index_counter = 0
#
df = pd.read_csv(path)
df_values = df.values
df_values_count = len(df_values)
df_headers = df.columns
df_header_count = len(df_headers)
#
print('DF size before outlier removal: ' + str(df_values_count))
# Out:
# DF size before outlier removal: 10000

# %% [markdown]
# # Data Representation
#
# ### Box Plot EEG Eye State data set representation

# %%
# Plot Box Plots
def plotBoxPlots(data, arrLabels, titleSuffix):
    fig = plt.figure()
    fig.set_figwidth(30)
    fig.set_figheight(30)

    ax1 = fig.add_subplot(1, 1, 1)
    ax1.set_title('Feature range: full - ' + titleSuffix)
    suppress = ax1.boxplot(data
                           , sym='b.'
                           , vert=False
                           , whis='range'
                           , labels=arrLabels
                           , meanline=True
                           , showbox=True
                           , showfliers=True
                           )
    plt.show()
    #
    fig = plt.figure()
    fig.set_figwidth(30)
    fig.set_figheight(30)
    ax2 = fig.add_subplot(1, 1, 1)
    ax2.set_title('Feature range: [5%, 95%] - ' + titleSuffix)
    suppress = ax2.boxplot(data
                           , sym='b.'
                           , vert=False
                           , whis=[5, 95]
                           , labels=arrLabels
                           , meanline=True
                           , showbox=True
                           , showfliers=False
                           )
    plt.show()
#
# Plotting Box Plots
plotBoxPlots(df_values[:,0:df_header_count], df_headers, 'Extreme outliers excluded')

# %% [markdown]
# ### Scatter Plot representation of the EEG Eye State data set

# %%
from IPython.display import Image
# Red = EyeClosed, Blue = EyeOpen
Image(filename="Images/Scatter plot ['AF4'] vs ['P7'] Raw.png")

# %%
from IPython.display import Image
# Red = EyeClosed, Blue = EyeOpen
Image(filename="Images/Scatter plot ['F8'] vs ['AF3'] Raw.png")

# %%
from IPython.display import Image
# Red = EyeClosed, Blue = EyeOpen
Image(filename="Images/Scatter plot ['F8'] vs ['P8'] Raw.png")

# %%
from IPython.display import Image
# Red = EyeClosed, Blue = EyeOpen
Image(filename="Images/Scatter plot ['FC'] vs ['AF3'] Raw.png")

# %%
from IPython.display import Image
# Red = EyeClosed, Blue = EyeOpen
Image(filename="Images/Scatter plot ['FC'] vs ['P8'] Raw.png")

# %%
from IPython.display import Image
# Red = EyeClosed, Blue = EyeOpen
Image(filename="Images/Scatter plot ['O1'] vs ['FC'] Raw.png")

# %% [markdown]
# # Data Representation
#
# ### Box Plots EEG Eye State data set excluding outliers

# %%
# Removing outliers
def get_outlier_indexes(df, df_col_count, outlier_value=5000):
    """ Takes a dataframe and returns the position of any outliers """
    outLierIndexes = set()
    upperLimit = outlier_value
    for x in range(df_col_count):
        df = np.array(df)
        outLiers = np.where(df[:, x] > upperLimit)[0]
        if len(outLiers) > 0:
            [(outLierIndexes.add(outLiers[i])) for i in range(len(outLiers))]
    #
    outLierIndexes = list(outLierIndexes)
    outLierIndexes.sort()
    return outLierIndexes
#
outlier_indexes = get_outlier_indexes(df_values, df_header_count)
print('Extreme outliers\nTotal:   ', len(outlier_indexes), \
    '\nIndexes: ', outlier_indexes)
# [(print(DataFrame(df).iloc[[outlier]])) for outlier in outlier_indexes]
df_values_pruned = np.delete(df_values, outlier_indexes, 0)
df_values_pruned_count = len(df_values_pruned)
df_pruned = pd.DataFrame(data=df_values_pruned, columns=df_headers)
#
print('DF size after outlier removal: ' + str(df_values_pruned_count))
# Out:
# Extreme outliers
# Total:    1
# Indexes:  [898]
# DF size after outlier removal: 9999

# %%
#
# Plotting Box Plots
eegDataNoOutLiers_y = df_pruned['eyeDetection']
eegDataNoOutLiers_X = df_pruned.drop('eyeDetection', 1)
plotBoxPlots(eegDataNoOutLiers_X.values[:,0:len(eegDataNoOutLiers_X.columns)], eegDataNoOutLiers_X.columns, 'Extreme outliers excluded')

# %% [markdown]
# ### Scatter Plot representation of the EEG Eye State data set (excluding outliers)

# %%
from IPython.display import Image
# Red = EyeClosed, Blue = EyeOpen
Image(filename="Images/Scatter plot ['AF4'] vs ['P7'].png")

# %%
# Red = EyeClosed, Blue = EyeOpen
Image(filename="Images/Scatter plot ['F8'] vs ['AF3'].png")

# %%
# Red = EyeClosed, Blue = EyeOpen
Image(filename="Images/Scatter plot ['F8'] vs ['P8'].png")

# %%
# Red = EyeClosed, Blue = EyeOpen
Image(filename="Images/Scatter plot ['FC'] vs ['AF3'].png")

# %%
# Red = EyeClosed, Blue = EyeOpen
Image(filename="Images/Scatter plot ['FC'] vs ['P8'].png")

# %%
# Red = EyeClosed, Blue = EyeOpen
Image(filename="Images/Scatter plot ['O1'] vs ['FC'].png")

# %% [markdown]
# # Time Series Analysis
#
# ### EEG Eye State data set time shifting (lag set to 0)

# %%
# Applying lag to timeseries data set, by shifting degree of n
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True):
    """
    Frame a time series as a supervised learning dataset.
    Arguments:
        data: Sequence of observations as a list or NumPy array.
        n_in: Number of lag observations as input (X).
        n_out: Number of observations as output (y).
        dropnan: Boolean whether or not to drop rows with NaN values.
    Returns:
        Pandas DataFrame of series framed for supervised learning.
    """
    n_vars = 1 if type(data) is list else data.shape[1]
    df = DataFrame(data)
    cols, names = list(), list()
    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [('var%d(t-%d)' % (j+1, i)) for j in range(n_vars)]
    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [('var%d(t)' % (j+1)) for j in range(n_vars)]
        else:
            names += [('var%d(t+%d)' % (j+1, i)) for j in range(n_vars)]
    # put it all together
    agg = concat(cols, axis=1)
    agg.columns = names
    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg
#
# N-Step Univariate Forecasting Shift
df_pruned_shifted = series_to_supervised(data=df_pruned, n_in=lag, n_out=1, dropnan=True)
#
# Removing any lag variables of var15(t-lag) (label)
if lag > 0:
    for i in range(1,lag+1):
        df_pruned_shifted = df_pruned_shifted.drop('var15(t-' + str(i) + ')', 1)
df_pruned_shifted_headers = df_pruned_shifted.columns
df_pruned_shifted_header_count = len(df_pruned_shifted_headers)
print(df_pruned_shifted_headers)
# Out:
# Index(['var1(t)', 'var2(t)', 'var3(t)', 'var4(t)', 'var5(t)', 'var6(t)',
#        'var7(t)', 'var8(t)', 'var9(t)', 'var10(t)', 'var11(t)', 'var12(t)',
#        'var13(t)', 'var14(t)', 'var15(t)'],
#       dtype='object')

# %% [markdown]
# ### Line plots of feature readings over time (117 seconds)

# %%
# AF3 line graph
Image(filename="Images/AF3.png")

# %%
# AF4 line graph
Image(filename="Images/AF4.png")

# %%
# F8 line graph
Image(filename="Images/F8.png")

# %%
# FC line graph
Image(filename="Images/FC.png")

# %%
# O1 line graph
Image(filename="Images/O1.png")

# %%
# P7 line graph
Image(filename="Images/P7.png")

# %%
# P8 line graph
Image(filename="Images/P8.png")

# %%
# eyeDetection line graph
Image(filename="Images/eyeDetection.png")

# %% [markdown]
# # Feature Selection - Filter Methods
#
# ### Pearson Correlation Matrix

# %%
# Plot Pearson's Correlation Matrix for shifted_df
eegDF = pd.DataFrame(data=df_pruned_shifted, columns=df_pruned_shifted_headers)
#
# Compute the correlation matrix
corr = eegDF.corr()
#
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True
#
# Set up the matplotlib figure
fig = plt.figure()
fig.set_figheight(20)
fig.set_figwidth(20)
#
ax = fig.add_subplot(1, 1, 1)
ax.set_title("Feature correlation matrix")
#
# Generate a custom diverging colormap
cmap = sns.diverging_palette(240, 20, as_cmap=True)
#
# Draw the heatmap
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=1.0, vmin=-1.0, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
plt.show()
#
# Store the upper triangle of the correlation matrix into an Excel sheet
corrUpperTri = corr.where(mask)
writer = pd.ExcelWriter('EEG_Shifted_Correlation_Matrix.xlsx')
corrUpperTri.to_excel(writer, 'CorrelationMatrix')
writer.save()

# %%
# Pearson's Correlation Matrix
Image(filename="Images/Correlation Matrix Excluding Outliers.png")

# %% [markdown]
# ### Filter Methods (Mutual Information Scoring)

# %%
from sklearn.metrics import mutual_info_score
import operator
mi_scores = {}
for column in df_pruned_shifted_headers:
    if column != 'var15(t)':
        mi_scores[column] = mutual_info_score(df_pruned_shifted[column], df_pruned_shifted['var15(t)'])
print('Mutual Information: ')
print(sorted(mi_scores.items(), key=operator.itemgetter(1), reverse=True))
# Out:
# Mutual Information:
# [('var1(t)', 0.068001631969438509), ('var14(t)', 0.061312983255733783), ('var6(t)', 0.056815681032305346), ('var13(t)', 0.056309625332207881), ('var7(t)', 0.04282873920644046), ('var11(t)', 0.040537269025248061), ('var2(t)', 0.03461132683140055), ('var12(t)', 0.0283772790896249), ('var9(t)', 0.02320555796089771), ('var3(t)', 0.020713608072078921), ('var4(t)', 0.02026262824227585), ('var10(t)', 0.020162418824560796), ('var8(t)', 0.019820144087840025), ('var5(t)', 0.0086360493779071828)]

# %% [markdown]
# ### Auto Correlation Plot for time series analysis

# %%
#
# Autocorrelation Plot
series = Series.from_csv(path, header=0)
print(series.values)
from statsmodels.graphics.tsaplots import plot_acf
if lag == 0:
    lag = None
plot_acf(series, lags=lag)
plt.show()
# Out:
# [ 4009.23  4004.62  4006.67 ...,  4009.23  4003.59  3997.95]
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:2849: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)

# %%
# Limited to lag 100
plot_acf(series, lags=100)
plt.show()

# %% [markdown]
# # Data normalization

# %%
# Splitting into feature and label sets
df_pruned_shifted_Y = df_pruned_shifted['var15(t)']
df_pruned_shifted_X = df_pruned_shifted.drop('var15(t)', 1)
df_pruned_shifted_X_headers = df_pruned_shifted_X.columns
df_pruned_shifted_X_values = df_pruned_shifted_X.values
df_pruned_shifted_X_pd = df_pruned_shifted_X
#
# L2 Normalization
# from sklearn.preprocessing import normalize
# df_pruned_shifted_X = normalize(df_pruned_shifted_X, norm='l2')
# df_pruned_shifted_X = normalize(df_pruned_shifted_X, norm='l1')
# df_pruned_shifted_Y = np.array(df_pruned_shifted_Y)
#
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df_pruned_shifted_X = scaler.fit_transform(df_pruned_shifted_X)
df_pruned_shifted_Y = np.array(df_pruned_shifted_Y)
print(df_pruned_shifted_X)
print(df_pruned_shifted_Y)
# Out:
# [[ 0.4436634   0.41224928  0.74164956 ...,  0.47689908  0.49343604
#    0.51187141]
#  [ 0.42808381  0.39390322  0.78475462 ...,  0.47077883  0.48555416
#    0.48535451]
#  [ 0.43845894  0.40206145  0.79902967 ...,  0.48613945  0.47506206
#    0.49930648]
#  ...,
#  [ 0.376073    0.41224928  0.64592275 ...,  0.44923797  0.4173043
#    0.43653621]
#  [ 0.36742143  0.3898042   0.68426945 ...,  0.47689908  0.41205824
#    0.41423482]
#  [ 0.33447111  0.36735912  0.6507744  ...,  0.46153846  0.40287125
#    0.41700889]]
# [ 0.  0.  0. ...,  0.  0.  0.]

# %% [markdown]
# # Feature Selection - Wrapper Methods
#
# ### Random Forest Feature Importance Ranking

# %%
#
# Feature importance ranked using RandomForest
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=500)
#
rf.fit(df_pruned_shifted_X, df_pruned_shifted_Y)
feature_importances = pd.DataFrame(rf.feature_importances_,
                                   index = df_pruned_shifted_X_headers,
                                    columns=['importance']).sort_values('importance', ascending=False)
std = np.std([tree.feature_importances_ for tree in rf.estimators_], axis=0)
print('Random Forest Classification For Feature Selection: ')
print(feature_importances)
#
# Plot the feature importance of the forest
fig = plt.figure()
fig.set_figheight(20)
fig.set_figwidth(20)
plt.title("RandomForest Feature importance")
objects = list(feature_importances.axes[0])
y_pos = np.arange(len(objects))
feature_importance = np.array(feature_importances)
plt.bar(y_pos, feature_importance[0], align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.show()
# Out:
# Random Forest Classification For Feature Selection:
#           importance
# var6(t)     0.113730
# var7(t)     0.100260
# var2(t)     0.094992
# var13(t)    0.087203
# var1(t)     0.080455
# var14(t)    0.075435
# var4(t)     0.069952
# var11(t)    0.067079
# var12(t)    0.060612
# var3(t)     0.057778
# var10(t)    0.051895
# var5(t)     0.051554
# var8(t)     0.050586
# var9(t)     0.038470

# %% [markdown]
# ### Gradient Boosting Feature Importance Ranking

# %%
# #
# # Feature importance ranked using Gradient Boosting
# from sklearn.ensemble import GradientBoostingClassifier
# gbc = GradientBoostingClassifier()
# gbc.fit(df_pruned_shifted_X, df_pruned_shifted_Y)
# feature_importances = pd.DataFrame({'feature': df_pruned_shifted_X_headers, 'importance': np.round(gbc.feature_importances_, 6)})
# feature_importances = feature_importances.sort_values('importance', ascending=False).set_index('feature')
# #
# print(feature_importances)
# #
# # Plot the feature importance of the forest
# fig = plt.figure()
# fig.set_figheight(20)
# fig.set_figwidth(20)
# plt.title("Gradient Boosting Feature importance")
# objects = list(feature_importances.axes[0])
# y_pos = np.arange(len(objects))
# feature_importance = np.array(feature_importances)
# plt.bar(y_pos, feature_importance[0], align='center', alpha=0.5)
# plt.xticks(y_pos, objects)
# plt.show()

# %% [markdown]
# ### Evaluation Metrics

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
#
class Scoring_Functions():
    #
    def __init__(self, y_pred, y_true):
        self.y_pred = y_pred
        self.y_true = y_true
    #
    def accuracy(self):
        # http://scikit-learn.org/stable/modules/generated/sklearn.metrics.accuracy_score.html#sklearn.metrics.accuracy_score
        return str(accuracy_score(self.y_true, self.y_pred) * 100) + "%"
    #
    def precision(self):
        # http: // scikit - learn.org / stable / modules / generated / sklearn.metrics.precision_score.html  # sklearn.metrics.precision_score
        return str(precision_score(self.y_true, self.y_pred, average='weighted')* 100) + '%'
    #
    def recall(self):
        # http://scikit-learn.org/stable/modules/generated/sklearn.metrics.recall_score.html#sklearn.metrics.recall_score
        return str(recall_score(self.y_true, self.y_pred, average='weighted') * 100) + '%'
    #
    def f_measure(self):
        # http://scikit-learn.org/stable/modules/generated/sklearn.metrics.f1_score.html#sklearn.metrics.f1_score
        return str(f1_score(self.y_true, self.y_pred, average='weighted') * 100) + '%'
    #
    def scoring_results(self):
        return "Accuracy: " + str(self.accuracy()) + "\nPrecision: " + str(self.precision()) + "\nRecall: " + str(self.recall()) + "\nFMeasure: " + str(self.f_measure())

# %% [markdown]
# ### Random Forest Feature Importance Wrapper Ranking (Backward Elimination)

# %%
# Wrapper Method - Random Forest Backward Feature Elimination
from numpy import sort
from sklearn.feature_selection import SelectFromModel
#
# Splitting into Training/Validating data subsets
test_size = (.2,.3,.4)# 80/20%, 70/30%, 60/40%
for t in test_size:
    X_train, X_test, y_train, y_test = train_test_split(df_pruned_shifted_X, df_pruned_shifted_Y, test_size=t, random_state=0)
    #
    rfc = RandomForestClassifier()
    rfc.fit(X_train, y_train)
    feature_importances = pd.DataFrame({'feature': df_pruned_shifted_X_headers, 'importance': np.round(rfc.feature_importances_, 6)})
    feature_importances = feature_importances.sort_values('importance', ascending=False).set_index('feature')
    #
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    #
    # make predictions for test data and evaluate
    pred_y = model.predict(X_test)
    #
    # Testing Classifier Accuracy
    sf = Scoring_Functions(y_pred=pred_y, y_true=y_test)
    print("RFC Accuracy with " + str(t) + " sub sampling: ")
    print(sf.scoring_results())
    print('-------------------------')
    #
    # fit model using each importance as a threshold
    thresholds = sort(model.feature_importances_)
    for thresh in thresholds:
        # selecting features using threshold
        selection = SelectFromModel(model, threshold=thresh, prefit=True)
        select_train_x = selection.transform(X_train)
        #
        # training model
        selection_model = RandomForestClassifier()
        selection_model.fit(select_train_x, y_train)
        #
        # evaluating model
        select_test_x = selection.transform(X_test)
        pred_y = selection_model.predict(select_test_x)
        sf = Scoring_Functions(y_pred=pred_y, y_true=y_test)
        print('Threshold: ' + str(thresh))
        print('Feature Count: ' + str(select_train_x.shape[1]))
        print(sf.scoring_results())
        print('-------------------------')
    print('#############################\n#############################\n#############################')
# Out:
# RFC Accuracy with 0.2 sub sampling:
# Accuracy: 90.9%
# Precision: 91.050512588%
# Recall: 90.9%
# FMeasure: 90.9267972329%
# -------------------------
# Threshold: 0.0417446420617
# Feature Count: 14
# Accuracy: 91.25%
# Precision: 91.3235592532%
# Recall: 91.25%
# FMeasure: 91.2673790794%
# -------------------------
# Threshold: 0.0486307432516
# Feature Count: 13
# Accuracy: 91.65%
# Precision: 91.6574157735%
# Recall: 91.65%
# FMeasure: 91.6531252627%
# -------------------------
# Threshold: 0.0546342068879
# Feature Count: 12
# Accuracy: 90.75%
# Precision: 90.8410846348%
# Recall: 90.75%
# FMeasure: 90.7705841938%
# -------------------------
# Threshold: 0.0551190994815
# Feature Count: 11
# Accuracy: 89.2%
# Precision: 89.439569631%
# Recall: 89.2%
# FMeasure: 89.2391098344%
# -------------------------
# Threshold: 0.0575997706547
# Feature Count: 10
# Accuracy: 90.15%
# Precision: 90.3200151515%
# Recall: 90.15%
# FMeasure: 90.1805179991%
# -------------------------
# Threshold: 0.0626622146676
# Feature Count: 9
# Accuracy: 90.35%
# Precision: 90.3547785598%
# Recall: 90.35%
# FMeasure: 90.3521825465%
# -------------------------
# Threshold: 0.0638366800053
# Feature Count: 8
# Accuracy: 87.85%
# Precision: 88.042625677%
# Recall: 87.85%
# FMeasure: 87.8888560294%
# -------------------------
# Threshold: 0.067034105809
# Feature Count: 7
# Accuracy: 86.15%
# Precision: 86.2589336107%
# Recall: 86.15%
# FMeasure: 86.1808206577%
# -------------------------
# Threshold: 0.0785552338883
# Feature Count: 6
# Accuracy: 84.2%
# Precision: 84.5203280725%
# Recall: 84.2%
# FMeasure: 84.2626059639%
# -------------------------
# Threshold: 0.0797008371676
# Feature Count: 5
# Accuracy: 80.2%
# Precision: 80.7119199935%
# Recall: 80.2%
# FMeasure: 80.2936772127%
# -------------------------
# Threshold: 0.0843707138217
# Feature Count: 4
# Accuracy: 78.05%
# Precision: 78.7222792005%
# Recall: 78.05%
# FMeasure: 78.1631802699%
# -------------------------
# Threshold: 0.100795622723
# Feature Count: 3
# Accuracy: 67.55%
# Precision: 68.3567689314%
# Recall: 67.55%
# FMeasure: 67.7232171039%
# -------------------------
# Threshold: 0.102015580104
# Feature Count: 2
# Accuracy: 61.65%
# Precision: 61.8024795252%
# Recall: 61.65%
# FMeasure: 61.7166770306%
# -------------------------
# Threshold: 0.103300549477
# Feature Count: 1
# Accuracy: 61.9%
# Precision: 61.5265000195%
# Recall: 61.9%
# FMeasure: 61.6283995094%
# -------------------------
# #############################
# #############################
# #############################
# RFC Accuracy with 0.3 sub sampling:
# Accuracy: 90.0333333333%
# Precision: 90.1477231286%
# Recall: 90.0333333333%
# FMeasure: 90.055497617%
# -------------------------
# Threshold: 0.0422414051972
# Feature Count: 14
# Accuracy: 90.8666666667%
# Precision: 91.0334363593%
# Recall: 90.8666666667%
# FMeasure: 90.8914714173%
# -------------------------
# Threshold: 0.0472650663823
# Feature Count: 13
# Accuracy: 90.1%
# Precision: 90.3035785285%
# Recall: 90.1%
# FMeasure: 90.1292012966%
# -------------------------
# Threshold: 0.0513241819095
# Feature Count: 12
# Accuracy: 89.9333333333%
# Precision: 90.0451187882%
# Recall: 89.9333333333%
# FMeasure: 89.9554079259%
# -------------------------
# Threshold: 0.052854916078
# Feature Count: 11
# Accuracy: 89.9666666667%
# Precision: 90.0753987327%
# Recall: 89.9666666667%
# FMeasure: 89.9883548225%
# -------------------------
# Threshold: 0.0611872409148
# Feature Count: 10
# Accuracy: 90.0333333333%
# Precision: 90.1537603936%
# Recall: 90.0333333333%
# FMeasure: 90.0561087155%
# -------------------------
# Threshold: 0.0667765909896
# Feature Count: 9
# Accuracy: 89.5333333333%
# Precision: 89.613479502%
# Recall: 89.5333333333%
# FMeasure: 89.5522039677%
# -------------------------
# Threshold: 0.0675024237267
# Feature Count: 8
# Accuracy: 88.0333333333%
# Precision: 88.1675030002%
# Recall: 88.0333333333%
# FMeasure: 88.0614017898%
# -------------------------
# Threshold: 0.0717942973664
# Feature Count: 7
# Accuracy: 86.2%
# Precision: 86.4485548074%
# Recall: 86.2%
# FMeasure: 86.2430382736%
# -------------------------
# Threshold: 0.0719644170843
# Feature Count: 6
# Accuracy: 86.2333333333%
# Precision: 86.4613135827%
# Recall: 86.2333333333%
# FMeasure: 86.2746205757%
# -------------------------
# Threshold: 0.0771987669782
# Feature Count: 5
# Accuracy: 83.3333333333%
# Precision: 83.6556603809%
# Recall: 83.3333333333%
# FMeasure: 83.3903925242%
# -------------------------
# Threshold: 0.0876217150799
# Feature Count: 4
# Accuracy: 80.1%
# Precision: 80.3875880293%
# Recall: 80.1%
# FMeasure: 80.1634367566%
# -------------------------
# Threshold: 0.0916259016457
# Feature Count: 3
# Accuracy: 68.5333333333%
# Precision: 69.3076792124%
# Recall: 68.5333333333%
# FMeasure: 68.6689114767%
# -------------------------
# Threshold: 0.104162856027
# Feature Count: 2
# Accuracy: 62.2666666667%
# Precision: 62.2532988112%
# Recall: 62.2666666667%
# FMeasure: 62.2598724785%
# -------------------------
# Threshold: 0.10648022062
# Feature Count: 1
# Accuracy: 61.7666666667%
# Precision: 61.2213959022%
# Recall: 61.7666666667%
# FMeasure: 61.1019622587%
# -------------------------
# #############################
# #############################
# #############################
# RFC Accuracy with 0.4 sub sampling:
# Accuracy: 90.2%
# Precision: 90.3490132153%
# Recall: 90.2%
# FMeasure: 90.2265030247%
# -------------------------
# Threshold: 0.0424922501688
# Feature Count: 14
# Accuracy: 89.3%
# Precision: 89.5260004026%
# Recall: 89.3%
# FMeasure: 89.3349831315%
# -------------------------
# Threshold: 0.0478629393361
# Feature Count: 13
# Accuracy: 89.45%
# Precision: 89.6287828947%
# Recall: 89.45%
# FMeasure: 89.4809328218%
# -------------------------
# Threshold: 0.0496471787601
# Feature Count: 12
# Accuracy: 89.525%
# Precision: 89.6071439124%
# Recall: 89.525%
# FMeasure: 89.54507573%
# -------------------------
# Threshold: 0.0500235033683
# Feature Count: 11
# Accuracy: 89.9%
# Precision: 90.0554380275%
# Recall: 89.9%
# FMeasure: 89.9277845782%
# -------------------------
# Threshold: 0.0582864191686
# Feature Count: 10
# Accuracy: 88.6%
# Precision: 88.8293256844%
# Recall: 88.6%
# FMeasure: 88.6372717476%
# -------------------------
# Threshold: 0.0656093795234
# Feature Count: 9
# Accuracy: 88.775%
# Precision: 88.9708904645%
# Recall: 88.775%
# FMeasure: 88.8091352738%
# -------------------------
# Threshold: 0.0656959821634
# Feature Count: 8
# Accuracy: 86.75%
# Precision: 86.9139010804%
# Recall: 86.75%
# FMeasure: 86.7858331712%
# -------------------------
# Threshold: 0.0658605148174
# Feature Count: 7
# Accuracy: 85.675%
# Precision: 85.8793952426%
# Recall: 85.675%
# FMeasure: 85.7179434447%
# -------------------------
# Threshold: 0.075062021272
# Feature Count: 6
# Accuracy: 84.0%
# Precision: 84.303205819%
# Recall: 84.0%
# FMeasure: 84.0571844775%
# -------------------------
# Threshold: 0.0864529986004
# Feature Count: 5
# Accuracy: 82.7%
# Precision: 82.9764291484%
# Recall: 82.7%
# FMeasure: 82.7586039565%
# -------------------------
# Threshold: 0.0875655897988
# Feature Count: 4
# Accuracy: 76.2%
# Precision: 77.0932349685%
# Recall: 76.2%
# FMeasure: 76.3152827417%
# -------------------------
# Threshold: 0.0902493353853
# Feature Count: 3
# Accuracy: 69.05%
# Precision: 69.8765529744%
# Recall: 69.05%
# FMeasure: 69.1986365662%
# -------------------------
# Threshold: 0.097797239709
# Feature Count: 2
# Accuracy: 61.95%
# Precision: 62.1580971022%
# Recall: 61.95%
# FMeasure: 62.0341042706%
# -------------------------
# Threshold: 0.117394647928
# Feature Count: 1
# Accuracy: 62.225%
# Precision: 61.7867344662%
# Recall: 62.225%
# FMeasure: 61.8380310888%
# -------------------------
# #############################
# #############################
# #############################

# %% [markdown]
# ### Gradient Boosting Feature Importance Wrapper Ranking (Backward Elimination)

# %%
#
# Splitting into Training/Validating data subsets
test_size = (.2,.3,.4)# 80/20%, 70/30%, 60/40%
for t in test_size:
    X_train, X_test, y_train, y_test = train_test_split(df_pruned_shifted_X, df_pruned_shifted_Y, test_size=t, random_state=0)
    #
    model = GradientBoostingClassifier()
    model.fit(X_train, y_train)
    #
    # make predictions for test data and evaluate
    pred_y = model.predict(X_test)
    #
    # Testing Classifier Accuracy
    sf = Scoring_Functions(y_pred=pred_y, y_true=y_test)
    print("GBC Accuracy with " + str(t) + " sub sampling: ")
    print(sf.scoring_results())
    print('-------------------------')
    #
    # fit model using each importance as a threshold
    thresholds = sort(model.feature_importances_)
    for thresh in thresholds:
        # selecting features using threshold
        selection = SelectFromModel(model, threshold=thresh, prefit=True)
        select_train_x = selection.transform(X_train)
        #
        # training model
        selection_model = GradientBoostingClassifier()
        selection_model.fit(select_train_x, y_train)
        #
        # evaluating model
        select_test_x = selection.transform(X_test)
        pred_y = selection_model.predict(select_test_x)
        sf = Scoring_Functions(y_pred=pred_y, y_true=y_test)
        print('Threshold: ' + str(thresh))
        print('Feature Count: ' + str(select_train_x.shape[1]))
        print(sf.scoring_results())
        print('-------------------------')
    print('#############################\n#############################\n#############################')
# Out:
# GBC Accuracy with 0.2 sub sampling:
# Accuracy: 84.35%
# Precision: 84.3432493471%
# Recall: 84.35%
# FMeasure: 84.2545398917%
# -------------------------
# Threshold: 0.00656156315934
# Feature Count: 14
# Accuracy: 84.35%
# Precision: 84.3432493471%
# Recall: 84.35%
# FMeasure: 84.2545398917%
# -------------------------
# Threshold: 0.0371602697674
# Feature Count: 13
# Accuracy: 84.65%
# Precision: 84.6476226258%
# Recall: 84.65%
# FMeasure: 84.556369798%
# -------------------------
# Threshold: 0.0434503423893
# Feature Count: 12
# Accuracy: 82.95%
# Precision: 82.9161465634%
# Recall: 82.95%
# FMeasure: 82.8535477985%
# -------------------------
# Threshold: 0.0451021392959
# Feature Count: 11
# Accuracy: 83.4%
# Precision: 83.3551942618%
# Recall: 83.4%
# FMeasure: 83.3323284035%
# -------------------------
# Threshold: 0.0475062995607
# Feature Count: 10
# Accuracy: 82.7%
# Precision: 82.6473305962%
# Recall: 82.7%
# FMeasure: 82.6398068227%
# -------------------------
# Threshold: 0.0530466030665
# Feature Count: 9
# Accuracy: 81.85%
# Precision: 81.7904067546%
# Recall: 81.85%
# FMeasure: 81.7814745866%
# -------------------------
# Threshold: 0.0563890868298
# Feature Count: 8
# Accuracy: 80.55%
# Precision: 80.4785447691%
# Recall: 80.55%
# FMeasure: 80.4647569035%
# -------------------------
# Threshold: 0.0606945721808
# Feature Count: 7
# Accuracy: 80.9%
# Precision: 80.8328540359%
# Recall: 80.9%
# FMeasure: 80.810349452%
# -------------------------
# Threshold: 0.0708870899614
# Feature Count: 6
# Accuracy: 80.1%
# Precision: 80.061211406%
# Recall: 80.1%
# FMeasure: 79.9343179533%
# -------------------------
# Threshold: 0.0756915071412
# Feature Count: 5
# Accuracy: 77.65%
# Precision: 77.5469667305%
# Recall: 77.65%
# FMeasure: 77.5427524873%
# -------------------------
# Threshold: 0.102260722292
# Feature Count: 4
# Accuracy: 75.9%
# Precision: 75.7734320917%
# Recall: 75.9%
# FMeasure: 75.7715252046%
# -------------------------
# Threshold: 0.125086426856
# Feature Count: 3
# Accuracy: 73.55%
# Precision: 73.4331216675%
# Recall: 73.55%
# FMeasure: 73.1524912571%
# -------------------------
# Threshold: 0.1373509562
# Feature Count: 2
# Accuracy: 67.2%
# Precision: 66.8496638475%
# Recall: 67.2%
# FMeasure: 66.8249927252%
# -------------------------
# Threshold: 0.138812421299
# Feature Count: 1
# Accuracy: 63.6%
# Precision: 63.0992681564%
# Recall: 63.6%
# FMeasure: 63.101627142%
# -------------------------
# #############################
# #############################
# #############################
# GBC Accuracy with 0.3 sub sampling:
# Accuracy: 84.3%
# Precision: 84.2882715458%
# Recall: 84.3%
# FMeasure: 84.2311566351%
# -------------------------
# Threshold: 0.00978861146695
# Feature Count: 14
# Accuracy: 84.3%
# Precision: 84.2882715458%
# Recall: 84.3%
# FMeasure: 84.2311566351%
# -------------------------
# Threshold: 0.0377876810552
# Feature Count: 13
# Accuracy: 84.3666666667%
# Precision: 84.3716618188%
# Recall: 84.3666666667%
# FMeasure: 84.2858652339%
# -------------------------
# Threshold: 0.0492295219089
# Feature Count: 12
# Accuracy: 82.9%
# Precision: 82.860687815%
# Recall: 82.9%
# FMeasure: 82.8578373241%
# -------------------------
# Threshold: 0.0505218569915
# Feature Count: 11
# Accuracy: 82.9333333333%
# Precision: 82.9065546512%
# Recall: 82.9333333333%
# FMeasure: 82.8595847173%
# -------------------------
# Threshold: 0.0525133470327
# Feature Count: 10
# Accuracy: 82.9333333333%
# Precision: 82.9145061152%
# Recall: 82.9333333333%
# FMeasure: 82.8507687252%
# -------------------------
# Threshold: 0.0541915952763
# Feature Count: 9
# Accuracy: 82.0333333333%
# Precision: 81.9905207714%
# Recall: 82.0333333333%
# FMeasure: 81.9701825214%
# -------------------------
# Threshold: 0.0564538199423
# Feature Count: 8
# Accuracy: 81.0333333333%
# Precision: 80.9821026615%
# Recall: 81.0333333333%
# FMeasure: 80.9689517242%
# -------------------------
# Threshold: 0.065156862381
# Feature Count: 7
# Accuracy: 80.8666666667%
# Precision: 80.8475862317%
# Recall: 80.8666666667%
# FMeasure: 80.7453822006%
# -------------------------
# Threshold: 0.0681120776373
# Feature Count: 6
# Accuracy: 80.4333333333%
# Precision: 80.4577628417%
# Recall: 80.4333333333%
# FMeasure: 80.2670127234%
# -------------------------
# Threshold: 0.0749603565543
# Feature Count: 5
# Accuracy: 77.9333333333%
# Precision: 77.8572216704%
# Recall: 77.9333333333%
# FMeasure: 77.8236764691%
# -------------------------
# Threshold: 0.0985736235381
# Feature Count: 4
# Accuracy: 76.6666666667%
# Precision: 76.5788521096%
# Recall: 76.6666666667%
# FMeasure: 76.5285861648%
# -------------------------
# Threshold: 0.101790363711
# Feature Count: 3
# Accuracy: 75.0%
# Precision: 74.9930619102%
# Recall: 75.0%
# FMeasure: 74.670474273%
# -------------------------
# Threshold: 0.122224148917
# Feature Count: 2
# Accuracy: 67.2666666667%
# Precision: 67.0398428128%
# Recall: 67.2666666667%
# FMeasure: 67.0683961905%
# -------------------------
# Threshold: 0.158696133587
# Feature Count: 1
# Accuracy: 58.2333333333%
# Precision: 57.0829491435%
# Recall: 58.2333333333%
# FMeasure: 53.6783212252%
# -------------------------
# #############################
# #############################
# #############################
# GBC Accuracy with 0.4 sub sampling:
# Accuracy: 84.6%
# Precision: 84.5761350672%
# Recall: 84.6%
# FMeasure: 84.5381108676%
# -------------------------
# Threshold: 0.0137516646957
# Feature Count: 14
# Accuracy: 84.6%
# Precision: 84.5761350672%
# Recall: 84.6%
# FMeasure: 84.5381108676%
# -------------------------
# Threshold: 0.040141831889
# Feature Count: 13
# Accuracy: 84.45%
# Precision: 84.4285978836%
# Recall: 84.45%
# FMeasure: 84.3829574493%
# -------------------------
# Threshold: 0.0409097845783
# Feature Count: 12
# Accuracy: 84.025%
# Precision: 83.9876740022%
# Recall: 84.025%
# FMeasure: 83.9837026995%
# -------------------------
# Threshold: 0.0534482071445
# Feature Count: 11
# Accuracy: 83.35%
# Precision: 83.3134529595%
# Recall: 83.35%
# FMeasure: 83.3205151738%
# -------------------------
# Threshold: 0.0547281780289
# Feature Count: 10
# Accuracy: 83.625%
# Precision: 83.5855187386%
# Recall: 83.625%
# FMeasure: 83.5841097869%
# -------------------------
# Threshold: 0.057348506094
# Feature Count: 9
# Accuracy: 81.775%
# Precision: 81.7228509967%
# Recall: 81.775%
# FMeasure: 81.7163816558%
# -------------------------
# Threshold: 0.0589803120352
# Feature Count: 8
# Accuracy: 81.7%
# Precision: 81.6491614259%
# Recall: 81.7%
# FMeasure: 81.6264564206%
# -------------------------
# Threshold: 0.0610082918206
# Feature Count: 7
# Accuracy: 80.325%
# Precision: 80.2649939214%
# Recall: 80.325%
# FMeasure: 80.2293641338%
# -------------------------
# Threshold: 0.061405916873
# Feature Count: 6
# Accuracy: 79.15%
# Precision: 79.0884627053%
# Recall: 79.15%
# FMeasure: 79.0167829707%
# -------------------------
# Threshold: 0.0742452833407
# Feature Count: 5
# Accuracy: 77.8%
# Precision: 77.7183002452%
# Recall: 77.8%
# FMeasure: 77.65572147%
# -------------------------
# Threshold: 0.104828067549
# Feature Count: 4
# Accuracy: 75.975%
# Precision: 75.8932023532%
# Recall: 75.975%
# FMeasure: 75.9150068782%
# -------------------------
# Threshold: 0.110038386081
# Feature Count: 3
# Accuracy: 70.4%
# Precision: 70.6049511509%
# Recall: 70.4%
# FMeasure: 70.4729298999%
# -------------------------
# Threshold: 0.118912313892
# Feature Count: 2
# Accuracy: 67.875%
# Precision: 67.712143419%
# Recall: 67.875%
# FMeasure: 67.7627210043%
# -------------------------
# Threshold: 0.150253255979
# Feature Count: 1
# Accuracy: 57.0%
# Precision: 55.3120026525%
# Recall: 57.0%
# FMeasure: 54.1335302401%
# -------------------------
# #############################
# #############################
# #############################

# %% [markdown]
# # Implementation

# %% [markdown]
# ### Logistic Regression (Using Grid Search)

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.model_selection import GridSearchCV
# #
# # Splitting into Training/Validating data subsets
# test_size = (.2,.3,.4)# 80/20%, 70/30%, 60/40%
# C = (1,2,5,7,10,13)
# solver = ('liblinear', 'sag', 'saga', 'newton-cg')
# index_counter = 0
# #
# # grid search to find optimum hyper parameters, test split, feature selection
# for ts in test_size:
#     for c in C:
#         for s in solver:
#             #
#             # Drop unwanted variables which decrease accuracy of overall prediction (as generated from RFC/GBC)
#             df_pruned_shifted_X_temp = df_pruned_shifted_X_pd
#             df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var9(t)', 1)
#             df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var8(t)', 1)
#             df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var10(t)', 1)
#             df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var5(t)', 1)
#             df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var3(t)', 1)
#             df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var12(t)', 1)
#             df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var11(t)', 1)
#             df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var4(t)', 1)
#             #
#             X_train, X_test, y_train, y_test = train_test_split(df_pruned_shifted_X_temp, df_pruned_shifted_Y, test_size=ts, random_state=0)
#             X_train = scaler.fit_transform(X_train)
#             X_test = scaler.fit_transform(X_test)
# #             X_train = normalize(X_train, norm='l2')
# #             X_test = normalize(X_test, norm='l2')
#             #
#             clf = LogisticRegression(C=c,solver=s)
#             clf.fit(X_train, y_train)
#             #
#             # make predictions for test data and evaluate
#             pred_y = clf.predict(X_test)
#             #
#             # Testing Classifier Accuracy
#             sf = Scoring_Functions(y_pred=pred_y, y_true=y_test)
#             print("{{" + str(index_counter) + "}} Logistic Regression Accuracy with params: TestSize(" + str(ts) + "), C(" + str(c) + "), solver(" + str(s) + ")")
#             print(sf.scoring_results())
#             print('-------------------------')
#             index_counter += 1

# %% [markdown]
# ### Linear Discriminant Analysis Classification

# %%
# from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
# #
# # Splitting into Training/Validating data subsets
# test_size = (.2,.3,.4)# 80/20%, 70/30%, 60/40%
# index_counter = 0
# #
# # grid search to find optimum test split, feature selection
# for ts in test_size:
#     #
#     # Drop unwanted variables which decrease accuracy of overall prediction (as generated from RFC/GBC)
#     df_pruned_shifted_X_temp = df_pruned_shifted_X_pd
#     df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var9(t)', 1)
#     df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var8(t)', 1)
#     df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var10(t)', 1)
#     df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var5(t)', 1)
#     df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var3(t)', 1)
#     df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var12(t)', 1)
#     df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var11(t)', 1)
#     df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var4(t)', 1)
#     X_train, X_test, y_train, y_test = train_test_split(df_pruned_shifted_X_temp, df_pruned_shifted_Y, test_size=ts, random_state=0)
#     X_train = scaler.fit_transform(X_train)
#     X_test = scaler.fit_transform(X_test)
# #     X_train = normalize(X_train, norm='l2')
# #     X_test = normalize(X_test, norm='l2')
#     #
#     clf = LinearDiscriminantAnalysis()
#     clf.fit(X_train,y_train)
#     #
#     # make predictions for test data and evaluate
#     pred_y = clf.predict(X_test)
#     #
#     # Testing Classifier Accuracy
#     sf = Scoring_Functions(y_pred=pred_y, y_true=y_test)
#     print("{{" + str(index_counter) + "}} Linear Discriminant Analysis Accuracy with params: TestSize(" + str(ts) + ")")
#     print(sf.scoring_results())
#     print('-------------------------')
#     index_counter += 1

# %% [markdown]
# ### Random Forest Classification (Using Grid Search)

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.model_selection import GridSearchCV
# #
# # Splitting into Training/Validating data subsets
# test_size = (.2,.3,.4)# 80/20%, 70/30%, 60/40%
# n_estimators = (1000,5000,10000)
# max_features = (6, 'sqrt', 'log2')
# criterion = ('gini','entropy')
# n_jobs = 6
# index_counter = 0
# #
# # grid search to find optimum hyper parameters, test split, feature selection
# for ts in test_size:
#     for n in n_estimators:
#         for m in max_features:
#             for c in criterion:
#                 #
#                 # Drop unwanted variables which decrease accuracy of overall prediction (as generated from RFC/GBC)
#                 df_pruned_shifted_X_temp = df_pruned_shifted_X_pd
#                 df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var9(t)', 1)
#                 df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var8(t)', 1)
#                 df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var10(t)', 1)
#                 df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var5(t)', 1)
#                 df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var3(t)', 1)
#                 df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var12(t)', 1)
#                 df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var11(t)', 1)
#                 df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var4(t)', 1)
#                 #
#                 X_train, X_test, y_train, y_test = train_test_split(df_pruned_shifted_X_temp, df_pruned_shifted_Y, test_size=ts, random_state=0)
#                 X_train = scaler.fit_transform(X_train)
#                 X_test = scaler.fit_transform(X_test)
# #                 X_train = normalize(X_train, norm='l2')
# #                 X_test = normalize(X_test, norm='l2')
#                 #
#                 clf = RandomForestClassifier(n_estimators=n, max_features=m, n_jobs=n_jobs, criterion=c)
#                 clf.fit(X_train, y_train)
#                 #
#                 # make predictions for test data and evaluate
#                 pred_y = clf.predict(X_test)
#                 #
#                 # Testing Classifier Accuracy
#                 sf = Scoring_Functions(y_pred=pred_y, y_true=y_test)
#                 print("{{" + str(index_counter) + "}} Random Forest Accuracy with params: TestSize(" + str(ts) + "), n_estimators(" + str(n) + "), max_features(" + str(m) + "), criterion(" + str(c) + ")")
#                 print(sf.scoring_results())
#                 print('-------------------------')
#                 index_counter += 1

# %% [markdown]
# ### SVM (Using Grid Search)

# %%
# from sklearn import svm
# #
# # Splitting into Training/Validating data subsets
# test_size = (.2,.3,.4)# 80/20%, 70/30%, 60/40%
# kernel = ('rbf','linear','sigmoid')
# C = (1,2,5,7,10,13)
# gamma = (.001,.01,.1,1,5,10,30)
# degree = 3
# index_counter = 0
# #
# # grid search to find optimum hyper parameters, test split, feature selection
# for ts in test_size:
#     for n in n_estimators:
#         for k in kernel:
#             for c in C:
#                 for g in gamma:
#                     #
#                     # Drop unwanted variables which decrease accuracy of overall prediction (as generated from RFC/GBC)
#                     df_pruned_shifted_X_temp = df_pruned_shifted_X_pd
#                     df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var9(t)', 1)
#                     #
#                     X_train, X_test, y_train, y_test = train_test_split(df_pruned_shifted_X_temp, df_pruned_shifted_Y, test_size=ts, random_state=0)
#                     X_train = scaler.fit_transform(X_train)
#                     X_test = scaler.fit_transform(X_test)
#                     #
#                     clf = svm.SVC(kernel=k, C=c, gamma=g, degree=degree)
#                     clf.fit(X_train, y_train)
#                     #
#                     # make predictions for validation data and evaluate
#                     pred_y = clf.predict(X_test)
#                     #
#                     # Testing Classifier Accuracy
#                     sf = Scoring_Functions(y_pred=pred_y, y_true=y_test)
#                     print("{{" + str(index_counter) + "}} SVM Accuracy with params: test_size(" + str(ts) + "), Kernel(" + str(k) + "), C(" + str(c) + "), Gamma(" + str(g) + ")")
#                     print(sf.scoring_results())
#                     print('-------------------------')
#                     index_counter += 1

# %% [markdown]
# # Test File Evaluation
#
# ### Test File Evaluation (Running trained model on completely unseen data)

# %%
# Training Model using training data, optimum hyper parameters and selected features
#
# Drop unwanted variables which decrease accuracy of overall prediction (as generated from RFC/GBC)
df_pruned_shifted_X_temp = df_pruned_shifted_X_pd
df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var9(t)', 1)
df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var8(t)', 1)
df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var10(t)', 1)
df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var5(t)', 1)
df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var3(t)', 1)
df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var12(t)', 1)
df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var11(t)', 1)
df_pruned_shifted_X_temp = df_pruned_shifted_X_temp.drop('var4(t)', 1)
#
X_train, X_test, y_train, y_test = train_test_split(df_pruned_shifted_X_temp, df_pruned_shifted_Y, test_size=.4, random_state=0)
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)
# X_train = normalize(X_train, norm='l2')
# X_test = normalize(X_test, norm='l2')
# X_train = normalize(X_train, norm='l1')
# X_test = normalize(X_test, norm='l1')
#
from sklearn import svm
kernel = 'rbf'
C = 5
g = 10
degree = 3
clf = svm.SVC(kernel=kernel, C=C, gamma=g, degree=degree)
clf.fit(X_train, y_train)
#
# n=1000
# m='sqrt'
# n_jobs=6
# c='entropy'
# max_depth = 2
# random_state=500
# clf = RandomForestClassifier(n_estimators=n, max_features=m, n_jobs=n_jobs, criterion=c, max_depth=max_depth, random_state=random_state)
# clf.fit(X_train, y_train)
#
# make predictions for test data and evaluate
pred_y = clf.predict(X_test)
#
# Testing Classifier Accuracy
sf = Scoring_Functions(y_pred=pred_y, y_true=y_test)
print("{{" + str(index_counter) + "}} SVM Accuracy with params: TestSize(" + str(.4) + "), kernel(" + str(kernel) + "), C(" + str(C) + "), gamma(" + str(g) + "), degree(" + str(degree) + ")")
print(sf.scoring_results())
print('-------------------------')
# Out:
# {{0}} SVM Accuracy with params: TestSize(0.4), kernel(rbf), C(5), gamma(10), degree(3)
# Accuracy: 81.0%
# Precision: 81.0857137377%
# Recall: 81.0%
# FMeasure: 80.7918366456%
# -------------------------

# %%
# Test File Evaluation
df_test = pd.read_csv(path_test)
df_test_values = df_test.values
df_test_values_count = len(df_test)
df_test_headers = df_test.columns
df_test_header_count = len(df_test_headers)
print('DF size before outlier removal: ' + str(df_test_values_count))
#
outlier_indexes = get_outlier_indexes(df_test_values, df_test_header_count)
print('Extreme outliers\nTotal:   ', len(outlier_indexes), \
    '\nIndexes: ', outlier_indexes)
# [(print(DataFrame(df).iloc[[outlier]])) for outlier in outlier_indexes]
df_values_pruned = np.delete(df_test_values, outlier_indexes, 0)
df_values_pruned_count = len(df_values_pruned)
df_pruned = pd.DataFrame(data=df_values_pruned, columns=df_test_headers)
print('DF size after outlier removal: ' + str(df_values_pruned_count))
#
# N-Step Univariate Forecasting Shift
lag = 0
df_pruned_shifted = series_to_supervised(data=df_pruned, n_in=lag, n_out=1, dropnan=True)
#
# Removing any lag variables of var15(t-lag) (label)
if lag > 0:
    for i in range(1,lag+1):
        df_pruned_shifted = df_pruned_shifted.drop('var15(t-' + str(i) + ')', 1)
df_pruned_shifted_headers = df_pruned_shifted.columns
df_pruned_shifted_header_count = len(df_pruned_shifted_headers)
print(df_pruned_shifted_headers)
#
# Feature/Label Selection
df_pruned_shifted_Y = df_pruned_shifted['var15(t)']
df_pruned_shifted_X = df_pruned_shifted.drop('var15(t)', 1)
df_pruned_shifted_X = df_pruned_shifted_X.drop('var9(t)', 1)
df_pruned_shifted_X = df_pruned_shifted_X.drop('var8(t)', 1)
df_pruned_shifted_X = df_pruned_shifted_X.drop('var10(t)', 1)
df_pruned_shifted_X = df_pruned_shifted_X.drop('var5(t)', 1)
df_pruned_shifted_X = df_pruned_shifted_X.drop('var3(t)', 1)
df_pruned_shifted_X = df_pruned_shifted_X.drop('var12(t)', 1)
df_pruned_shifted_X = df_pruned_shifted_X.drop('var11(t)', 1)
df_pruned_shifted_X = df_pruned_shifted_X.drop('var4(t)', 1)
#
# Feature MinMax Scaling
df_pruned_shifted_X = scaler.fit_transform(df_pruned_shifted_X)
df_pruned_shifted_Y2 = np.array(df_pruned_shifted_Y)
# df_pruned_shifted_X = normalize(df_pruned_shifted_X, norm='l1')
# df_pruned_shifted_Y = np.array(df_pruned_shifted_Y)
# df_pruned_shifted_X = normalize(df_pruned_shifted_X, norm='l2')
# df_pruned_shifted_Y = np.array(df_pruned_shifted_Y)
#
# Run data on best established model
pred_y2 = clf.predict(df_pruned_shifted_X)
#
# Testing Classifier Accuracy
sf = Scoring_Functions(y_pred=pred_y2, y_true=df_pruned_shifted_Y2)
print("Test Metrics: ")
print(sf.scoring_results())
print('-------------------------')
# Out:
# DF size before outlier removal: 4980
# Extreme outliers
# Total:    3
# Indexes:  [386, 1509, 3179]
# DF size after outlier removal: 4977
# Index(['var1(t)', 'var2(t)', 'var3(t)', 'var4(t)', 'var5(t)', 'var6(t)',
#        'var7(t)', 'var8(t)', 'var9(t)', 'var10(t)', 'var11(t)', 'var12(t)',
#        'var13(t)', 'var14(t)', 'var15(t)'],
#       dtype='object')
# Test Metrics:
# Accuracy: 78.4408278079%
# Precision: 77.3841096168%
# Recall: 78.4408278079%
# FMeasure: 77.8011786024%
# -------------------------

# %%
# Roc curve
from sklearn.metrics import roc_curve, auc
#
# Compute fpr, tpr, thresholds and roc auc
fpr, tpr, thresholds = roc_curve(df_pruned_shifted_Y, pred_y)
roc_auc = auc(fpr, tpr)
fpr2, tpr2, thresholds2 = roc_curve(df_pruned_shifted_Y2, pred_y2)
roc_auc2 = auc(fpr2, tpr2)
#
# Plot ROC curve
plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc)
plt.plot(fpr, tpr, label='ROC curve (area = %0.3f)' % roc_auc2)
plt.plot([0, 1], [0, 1], 'k--')  # random predictions curve
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate or (1 - Specifity)')
plt.ylabel('True Positive Rate or (Sensitivity)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1578-3fd43f055e56> in <module>()
#       3 #
#       4 # Compute fpr, tpr, thresholds and roc auc
# ----> 5 fpr, tpr, thresholds = roc_curve(df_pruned_shifted_Y, pred_y)
#       6 roc_auc = auc(fpr, tpr)
#       7 fpr2, tpr2, thresholds2 = roc_curve(df_pruned_shifted_Y2, pred_y2)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     532     """
#     533     fps, tps, thresholds = _binary_clf_curve(
# --> 534         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     535
#     536     # Attempt to drop thresholds corresponding to points in between and
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     318         raise ValueError("{0} format is not supported".format(y_type))
#     319
# --> 320     check_consistent_length(y_true, y_score, sample_weight)
#     321     y_true = column_or_1d(y_true)
#     322     y_score = column_or_1d(y_score)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     202     if len(uniques) > 1:
#     203         raise ValueError("Found input variables with inconsistent numbers of"
# --> 204                          " samples: %r" % [int(l) for l in lengths])
#     205
#     206
#
# ValueError: Found input variables with inconsistent numbers of samples: [4977, 4000]
